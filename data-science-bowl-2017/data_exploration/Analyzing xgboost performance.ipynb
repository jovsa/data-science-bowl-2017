# %%
import glob
import os
import re
import pandas as pd
import numpy as np
import SimpleITK as sitk
import matplotlib.pyplot as plt
from tqdm import tqdm
import time
from datetime import timedelta
import sys
import datetime
import tensorflow as tf
import math
from sklearn import cross_validation
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier as RF
import scipy as sp
from sklearn.decomposition import PCA
import sklearn.metrics
# Out:
# /home/plexadmin/.virtualenvs/data-science-bowl-2017/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
OUTPUT_PATH = '/kaggle/dev/data-science-bowl-2017-data/submissions/'
DATA_PATH = '/kaggle/dev/data-science-bowl-2017-data/stage1_features/'
TENSORBOARD_SUMMARIES = '/kaggle/dev/data-science-bowl-2017-data/tensorboard_summaries/'
MODELS = '/kaggle_2/luna/luna16/models/'
MODEL_CHECKPOINTS = '/kaggle/dev/data-science-bowl-2017-data/models/checkpoints/'
MODEL_PATH = '/kaggle_2/luna/luna16/models/e03f0475-091e-4821-862e-ae5303d670c8/'
STAGE1 = '/kaggle/dev/data-science-bowl-2017-data/stage1/'
LABELS = '/kaggle/dev/data-science-bowl-2017-data/stage1_labels.csv'
STAGE1_SUBMISSION = '/kaggle/dev/data-science-bowl-2017-data/stage1_sample_submission.csv'
NAIVE_SUBMISSION = '/kaggle/dev/jovan/data-science-bowl-2017/data-science-bowl-2017/submissions/naive_submission.csv'

# %%
def get_inputs():
    labels = pd.read_csv(LABELS)
    input_features = {}

    for features in glob.glob(DATA_PATH + '*_transfer_values.npy'):
        n = re.match('([a-f0-9].*)_transfer_values.npy', os.path.basename(features))
        patient_id = n.group(1)
        predictions = np.array([np.mean(np.load(DATA_PATH + patient_id + '_predictions.npy'), axis=0)])
        transfer_values = np.array(np.load(DATA_PATH + patient_id + '_transfer_values.npy'))
        transfer_values = sp.misc.imresize(transfer_values, (100, 100))
        transfer_values = transfer_values.flatten()
        feature_val = transfer_values
        try:
            label_val = int(labels.loc[labels['id'] == patient_id, 'cancer'])
        except TypeError:
            continue
        input_features[patient_id] = [feature_val, label_val]
        print('Patient {} predictions {} transfer_values {}'.format(patient_id, predictions.shape, transfer_values.shape))

    return input_features

# %%
def train_xgboost(trn_x, val_x, trn_y, val_y):

    clf = xgb.XGBRegressor(max_depth=10,
                           gamma=0.5,
                           objective="binary:logistic",
                           n_estimators=1500,
                           min_child_weight=6,
                           learning_rate=0.005,
                           nthread=8,
                           subsample=0.80,
                           colsample_bytree=0.80,
                           seed=79,
                           max_delta_step=1,
                           reg_alpha=0.1,
                           reg_lambda=0.5)
    clf.fit(trn_x, trn_y, eval_set=[(val_x, val_y)], verbose=True, eval_metric='logloss', early_stopping_rounds=50)
    return clf

# %%
inputs = get_inputs()
# Out:
# Patient 6ee742b62985570a1f3a142eb7e49188 predictions (1, 7) transfer_values (10000,)
# Patient d6d5ed3055d084a6abf0f97af3fe2ff0 predictions (1, 7) transfer_values (10000,)
# Patient 645e7f46eb9b834153ecf8e2b2921fe5 predictions (1, 7) transfer_values (10000,)
# Patient e6d8b2631843a24e6761f2723ea30788 predictions (1, 7) transfer_values (10000,)
# Patient f0f72264cd822301852578cc71288d3c predictions (1, 7) transfer_values (10000,)
# Patient a88c585e7d81744eec091a6f0600bd7b predictions (1, 7) transfer_values (10000,)
# Patient 39c3a2d2ca67bc7a1a22240ea571d50c predictions (1, 7) transfer_values (10000,)
# Patient 74b542d34b61740c1933d2c953403aa6 predictions (1, 7) transfer_values (10000,)
# Patient 174a9fc87f54d6def3730954fbafc99d predictions (1, 7) transfer_values (10000,)
# Patient 080e6a00e69888fd620894f9fd0714b1 predictions (1, 7) transfer_values (10000,)
# Patient 118be21b7e0c3058b29a524686391c66 predictions (1, 7) transfer_values (10000,)
# Patient f76143416ee2c8e1251f45f108fed468 predictions (1, 7) transfer_values (10000,)
# Patient 1a91ca95390756518700877893ac195b predictions (1, 7) transfer_values (10000,)
# Patient 6ae190bcd3fd9c581db4120f4465d65a predictions (1, 7) transfer_values (10000,)
# Patient ce8b0816304e079bb99c6c25b4fa4b88 predictions (1, 7) transfer_values (10000,)
# Patient 61ce76681b4a68b8d0f3b724c1e844b3 predictions (1, 7) transfer_values (10000,)
# Patient 245fe0c86269602b0dab44c345b0b412 predictions (1, 7) transfer_values (10000,)
# Patient 9626af3a0a37c4fa5187447f01aa69da predictions (1, 7) transfer_values (10000,)
# Patient 9842a3b9dfabab4ae8642d9953058ce4 predictions (1, 7) transfer_values (10000,)
# Patient a79023a82079a7431ef2496acbef29de predictions (1, 7) transfer_values (10000,)
# Patient 98ea0b7d586e5e888e31633772f4df94 predictions (1, 7) transfer_values (10000,)
# Patient 2895ce2fe73dd62554326c3ab1c3b686 predictions (1, 7) transfer_values (10000,)
# Patient 2346e52f9370d9dd58172eb44b2b5d87 predictions (1, 7) transfer_values (10000,)
# Patient 61630ec628631f7fe3980f869e1a4fbe predictions (1, 7) transfer_values (10000,)
# Patient 380eb569a5750648434cc8ae8da4a0a9 predictions (1, 7) transfer_values (10000,)
# Patient fe5c37e82b412833b8ad0abb57978377 predictions (1, 7) transfer_values (10000,)
# Patient 3aedb9550977ed35e7d44555207ef739 predictions (1, 7) transfer_values (10000,)
# Patient 1edf5480bf676f8342a7d516bab58fa0 predictions (1, 7) transfer_values (10000,)
# Patient 186a0877503b047a77eb9b38083be9c1 predictions (1, 7) transfer_values (10000,)
# Patient 024efb7a1e67dc820eb61cbdaa090166 predictions (1, 7) transfer_values (10000,)
# Patient 7051fc0fcf2344a2967d9a1a5478208e predictions (1, 7) transfer_values (10000,)
# Patient a19a122fe9a790576b57c6bd5cf9ff5c predictions (1, 7) transfer_values (10000,)
# Patient 54162a514a5e2beb54e4b7aff41f5dfe predictions (1, 7) transfer_values (10000,)
# Patient 00986bebc45e12038ef0ce3e9962b51a predictions (1, 7) transfer_values (10000,)
# Patient c26fbd6a185271f820953be327b5307f predictions (1, 7) transfer_values (10000,)
# Patient 55eace190c5917cdfb390ca652149fbc predictions (1, 7) transfer_values (10000,)
# Patient 55d88980822c2e5d39b3d0ec172fa101 predictions (1, 7) transfer_values (10000,)
# Patient d8ed783494996f55a587270a212f7d5b predictions (1, 7) transfer_values (10000,)
# Patient 00cba091fa4ad62cc3200a657aeb957e predictions (1, 7) transfer_values (10000,)
# Patient 1dab3271160e1380c5a70a1e3ba40cb7 predictions (1, 7) transfer_values (10000,)
# Patient 750c11a0a87833e0bb26441b52b51399 predictions (1, 7) transfer_values (10000,)
# Patient f207bb8bcccdc76143380849402a4f21 predictions (1, 7) transfer_values (10000,)
# Patient 29d92a1e253cef2c7f34c6db26ce11e3 predictions (1, 7) transfer_values (10000,)
# Patient d2b47d9034d38a410f00dabba9754d91 predictions (1, 7) transfer_values (10000,)
# Patient 990fbe3f0a1b53878669967b9afd1441 predictions (1, 7) transfer_values (10000,)
# Patient a784a51caee14229d46777f2a9770a5f predictions (1, 7) transfer_values (10000,)
# Patient 415ea74bca59eb0ecd5ebb9c2c545f9d predictions (1, 7) transfer_values (10000,)
# Patient f83c62177ee552891d22df33be12ab07 predictions (1, 7) transfer_values (10000,)
# Patient 7faa456389e1ffde464819d0b1360188 predictions (1, 7) transfer_values (10000,)
# Patient 5267ea7baf6332f29163064aecf6e443 predictions (1, 7) transfer_values (10000,)
# Patient eba4bfb93928d424ff21b5be96b5c09b predictions (1, 7) transfer_values (10000,)
# Patient 408646e125230c495be91fe171da736e predictions (1, 7) transfer_values (10000,)
# Patient a53a4a019a24541c277e0a84301d8ec5 predictions (1, 7) transfer_values (10000,)
# Patient 8ad1af382994ce945a5034fab202d402 predictions (1, 7) transfer_values (10000,)
# Patient 32cda856b7ec759fd3ebaa363c505e88 predictions (1, 7) transfer_values (10000,)
# Patient 72a1e35c34052e163f61585ba0c9daf4 predictions (1, 7) transfer_values (10000,)
# Patient d43c9dd1be361b9302c9343af09cc23e predictions (1, 7) transfer_values (10000,)
# Patient 2fa939efbc3e1c2bc57ba5a98922ff3b predictions (1, 7) transfer_values (10000,)
# Patient 8a2de07f6e9dbb8c6e4bfad7e83b3f0a predictions (1, 7) transfer_values (10000,)
# Patient c1ba619e3b49e0cb7798bd10465c2b29 predictions (1, 7) transfer_values (10000,)
# Patient 8cb4c49a88d8ecb99d97cf5d707d58d7 predictions (1, 7) transfer_values (10000,)
# Patient a305389fe87d54597dfad222e47abac5 predictions (1, 7) transfer_values (10000,)
# Patient a0cdb677841933136fd15257e3c47fe6 predictions (1, 7) transfer_values (10000,)
# Patient 149ff4b37a684a73869d2d88e3fd4d0e predictions (1, 7) transfer_values (10000,)
# Patient 7bfba4540956c0b2c5b78b3623a4855d predictions (1, 7) transfer_values (10000,)
# Patient eed4db0cb0576c274de569e98a56a270 predictions (1, 7) transfer_values (10000,)
# Patient 3b908e86ea0f7cbd05dd8e0ea6d45d79 predictions (1, 7) transfer_values (10000,)
# Patient 398208da1bcb6a88e11a7314065f13ff predictions (1, 7) transfer_values (10000,)
# Patient 0334c8242ce7ee1a6c1263096e4cc535 predictions (1, 7) transfer_values (10000,)
# Patient 15aa585fb2d3018b295df8619f2d1cf7 predictions (1, 7) transfer_values (10000,)
# Patient 3a1a293ecad44010da9907bfc91d94cd predictions (1, 7) transfer_values (10000,)
# Patient 5fe048f36bd2da6bdb63d8ff3c4022cd predictions (1, 7) transfer_values (10000,)
# Patient 274297dd9a4f66148754944ae2b6731c predictions (1, 7) transfer_values (10000,)
# Patient b8bb02d229361a623a4dc57aa0e5c485 predictions (1, 7) transfer_values (10000,)
# Patient b7045ebff6dbb0023087e0399d00b873 predictions (1, 7) transfer_values (10000,)
# Patient c610439ebef643c7fd4b30de8088bb55 predictions (1, 7) transfer_values (10000,)
# Patient 2619ed1e4eca954af4dcbc4436ef8467 predictions (1, 7) transfer_values (10000,)
# Patient 74b3ef4c2125d636980a19754702dbb9 predictions (1, 7) transfer_values (10000,)
# Patient df1354de25723c9a55e1241d4c40ffe2 predictions (1, 7) transfer_values (10000,)
# Patient 4d8f4de444a1f453e7ad32d067b0f630 predictions (1, 7) transfer_values (10000,)
# Patient d6fe4bdde1a2cc3dc4efe22becfe22fd predictions (1, 7) transfer_values (10000,)
# Patient c2e546795f1ea2bd7f89ab3b4d13e761 predictions (1, 7) transfer_values (10000,)
# Patient c14816a1a9a6852c6b0d88fe5585c8bb predictions (1, 7) transfer_values (10000,)
# Patient 086f95a932c83faed289854083f48831 predictions (1, 7) transfer_values (10000,)
# Patient 4b7f72b889e85b479305f8fbc8cc4f48 predictions (1, 7) transfer_values (10000,)
# Patient 40c044145f5c87c12bd8c725924add3c predictions (1, 7) transfer_values (10000,)
# Patient 6a08bc7a3156caf9b07bbb1f9b2861d2 predictions (1, 7) transfer_values (10000,)
# Patient f55b8ee990408001671d76c3595afacf predictions (1, 7) transfer_values (10000,)
# Patient d74af71db9023b65737ee37ede219422 predictions (1, 7) transfer_values (10000,)
# Patient aea6f1621333074412b9a6acdcda31a9 predictions (1, 7) transfer_values (10000,)
# Patient 1be4cf2de84adac4de0e090c9a15461c predictions (1, 7) transfer_values (10000,)
# Patient ca3cdb2e771df9989df5a9cb0296c44c predictions (1, 7) transfer_values (10000,)
# Patient 01f1140c8e951e2a921b61c9a7e782c2 predictions (1, 7) transfer_values (10000,)
# Patient 6ddb331865608b8dfb8cac6d873eaf62 predictions (1, 7) transfer_values (10000,)
# Patient d2285c33945ab3421d753b4fc59ac3ce predictions (1, 7) transfer_values (10000,)
# Patient 4b8e47f2a5edda13b971da27317bfc6f predictions (1, 7) transfer_values (10000,)
# Patient 4dade0813da186d968b4b8c4952cbb0c predictions (1, 7) transfer_values (10000,)
# Patient f7cdd95c94818875ece1175561025038 predictions (1, 7) transfer_values (10000,)
# Patient 834dd009c49e7faaf8e4caba668a2d8f predictions (1, 7) transfer_values (10000,)
# Patient ab9e5f1718f2af09030dd33b531f066c predictions (1, 7) transfer_values (10000,)
# Patient 83463d2951670b7e8c3efd7594a13e10 predictions (1, 7) transfer_values (10000,)
# Patient c4c801ae039ba335fa32df7d84e4decb predictions (1, 7) transfer_values (10000,)
# Patient bbed0d350caad0e19e5b0fc858097ce4 predictions (1, 7) transfer_values (10000,)
# Patient e537c91cdfa97d20a39df7ef04a52570 predictions (1, 7) transfer_values (10000,)
# Patient bd87def5b7e1ec4f0057cde049995d83 predictions (1, 7) transfer_values (10000,)
# Patient de4d3724030397e71d2ac2ab16df5fba predictions (1, 7) transfer_values (10000,)
# Patient fa45178d023325b255a3d4fc3e96cb7d predictions (1, 7) transfer_values (10000,)
# Patient 23e309ef3a674bcd9c8df40614b93a8e predictions (1, 7) transfer_values (10000,)
# Patient 9397a41c9e819a92eb5c86e0e652d7c1 predictions (1, 7) transfer_values (10000,)
# Patient f3eafe72b1e9528116f3c430ab73a2ae predictions (1, 7) transfer_values (10000,)
# Patient 03ff23e445787886f8b0cb192b3c154d predictions (1, 7) transfer_values (10000,)
# Patient e42815372aa308f5943847ad06f529de predictions (1, 7) transfer_values (10000,)
# Patient d287819450e57ae8c883ed31dc4dc3a3 predictions (1, 7) transfer_values (10000,)
# Patient 73b28e2eadad587c9a8ac6c7186dd51b predictions (1, 7) transfer_values (10000,)
# Patient aa2747369e1a0c724bea611ea7e5ffcf predictions (1, 7) transfer_values (10000,)
# Patient e572e978c2b50aca781e6302937e5b13 predictions (1, 7) transfer_values (10000,)
# Patient aa528ce110f888679a4027513aeb442b predictions (1, 7) transfer_values (10000,)
# Patient 91ee390b30927af8804d1f2adf2aefa8 predictions (1, 7) transfer_values (10000,)
# Patient 1e0f8048728717064645cb758eb89279 predictions (1, 7) transfer_values (10000,)
# Patient b280f1f464aa5e0de843229de12fc1aa predictions (1, 7) transfer_values (10000,)
# Patient 198d3ff4979a9a89f78ac4b4a0fe0638 predictions (1, 7) transfer_values (10000,)
# Patient 75150225ab1f5d910bc64ad68ea4d221 predictions (1, 7) transfer_values (10000,)
# Patient afb37b10bd304fa2c7b70cfaf1f489ed predictions (1, 7) transfer_values (10000,)
# Patient 399a263bdfbf26c6969d8af98774be8c predictions (1, 7) transfer_values (10000,)
# Patient 975c90ab2afd216efbb6b772a22ba3d9 predictions (1, 7) transfer_values (10000,)
# Patient 31e82ed2c875eae8dfbfd70ac440458a predictions (1, 7) transfer_values (10000,)
# Patient c84e28d37dcc14a268b760bf16213cfa predictions (1, 7) transfer_values (10000,)
# Patient fd64b23b8cd8c371c8f76fbb503e4e0e predictions (1, 7) transfer_values (10000,)
# Patient e00832e96709eb85f8e0e608ca02c2b5 predictions (1, 7) transfer_values (10000,)
# Patient 4b6b53281fe1fe797e181a5287df0f9a predictions (1, 7) transfer_values (10000,)
# Patient 77d6f5203d46073369d7038b2d58e320 predictions (1, 7) transfer_values (10000,)
# Patient 7a82802a862a267d58aa2171645f1181 predictions (1, 7) transfer_values (10000,)
# Patient 7ae953bb9e0356d2990ee6655c8bd168 predictions (1, 7) transfer_values (10000,)
# Patient 1acbe17dc8f9f59d2fd167b2aa6c650f predictions (1, 7) transfer_values (10000,)
# Patient 1344e604281e68ac71f25c02e7637992 predictions (1, 7) transfer_values (10000,)
# Patient 191fa0e017185de2c802bbe94edad2ed predictions (1, 7) transfer_values (10000,)
# Patient 3f057e68a02e9951b268227649f4a7d6 predictions (1, 7) transfer_values (10000,)
# Patient 9759889dcee7ed0043d06e03fb44060d predictions (1, 7) transfer_values (10000,)
# Patient 43933b4021d93dd64854f318656c7d1e predictions (1, 7) transfer_values (10000,)
# Patient 323792e42c4f43448b2b1a9651ecb779 predictions (1, 7) transfer_values (10000,)
# Patient 89960d9a801625bf76e9e1047acc5cd5 predictions (1, 7) transfer_values (10000,)
# Patient f55f99177e8b4b267c71b4e5fa4116be predictions (1, 7) transfer_values (10000,)
# Patient cc24c86f88a9d17c04255a4d264030e6 predictions (1, 7) transfer_values (10000,)
# Patient 77941d758eae521a00ef225e306eda08 predictions (1, 7) transfer_values (10000,)
# Patient 91d29bc19205f8eb9a63de5b774a5575 predictions (1, 7) transfer_values (10000,)
# Patient 432f8765e6b590ec00cc34c8d88456da predictions (1, 7) transfer_values (10000,)
# Patient 74b68f9442209bace31aa62027fbb79a predictions (1, 7) transfer_values (10000,)
# Patient 07fdb853ff90ce3c6d5c91f619ed714e predictions (1, 7) transfer_values (10000,)
# Patient 86515f063b3a30af09ba4d0322edf7b1 predictions (1, 7) transfer_values (10000,)
# Patient f5717f7cbc08d8bd942cd4c1128e3339 predictions (1, 7) transfer_values (10000,)
# Patient 58e4646cbead2fc4a6a1f86bf806e76f predictions (1, 7) transfer_values (10000,)
# Patient 13bb12b3b27d5a7b4b142503a1ae9e73 predictions (1, 7) transfer_values (10000,)
# Patient dcf5fd36b9fff9183f63df286bf8eef9 predictions (1, 7) transfer_values (10000,)
# Patient 402a18fa05523f80abb1e6d97793cc19 predictions (1, 7) transfer_values (10000,)
# Patient 2505ca2e3cd132f69fde96ba4bb50f7b predictions (1, 7) transfer_values (10000,)
# Patient c5887c21bafb90eb8534e1a632ff2754 predictions (1, 7) transfer_values (10000,)
# Patient 21d449f3ae00ea302e5aa15d7df65465 predictions (1, 7) transfer_values (10000,)
# Patient a2fe50d59500281851fce256e922b675 predictions (1, 7) transfer_values (10000,)
# Patient a6195eb9162fc40d5fa2fdb1239dd788 predictions (1, 7) transfer_values (10000,)
# Patient d89499632a4c7bde0923003497ffc5ea predictions (1, 7) transfer_values (10000,)
# Patient 3c2dbbdeb857504a8b501fc013b99c90 predictions (1, 7) transfer_values (10000,)
# Patient 5d240c6a6d3009e61cb09ce49f641b4c predictions (1, 7) transfer_values (10000,)
# Patient 94cd77da118cc1d667cd9732853f0c48 predictions (1, 7) transfer_values (10000,)
# Patient 40c95c9be0bd7c290534ce374c58bec9 predictions (1, 7) transfer_values (10000,)
# Patient f29d00ddf6d9846aa600c3f0edf5f952 predictions (1, 7) transfer_values (10000,)
# Patient e6f4757b8f315f31559c5c256cb8dead predictions (1, 7) transfer_values (10000,)
# Patient c3e8db4f544e2d4ecb01c59551eb8ef0 predictions (1, 7) transfer_values (10000,)
# Patient 0c59313f52304e25d5a7dcf9877633b1 predictions (1, 7) transfer_values (10000,)
# Patient f44dd045f6dcb1e477e6d3dc0f29d7e8 predictions (1, 7) transfer_values (10000,)
# Patient 186d95f7c17fd666726c10251072d44b predictions (1, 7) transfer_values (10000,)
# Patient 919b9f74bcee297abd6e217d185a025d predictions (1, 7) transfer_values (10000,)
# Patient 35ab1899e939be4e67923a1624c91365 predictions (1, 7) transfer_values (10000,)
# Patient 8369f716ca2d51c934e7f6d44cb156e9 predictions (1, 7) transfer_values (10000,)
# Patient d0baf38ff8d974e7b59c23fd43713de9 predictions (1, 7) transfer_values (10000,)
# Patient 0bd0e3056cbf23a1cb7f0f0b18446068 predictions (1, 7) transfer_values (10000,)
# Patient e3423505ef6b43f03c5d7bde52a5a78c predictions (1, 7) transfer_values (10000,)
# Patient 9569bb8d5fc4461461078b2e2ca29f1f predictions (1, 7) transfer_values (10000,)
# Patient 35105d801880bd889bac5ee3771ed38b predictions (1, 7) transfer_values (10000,)
# Patient 2488c5b32e837dc848fe6fe4b1bbb7cb predictions (1, 7) transfer_values (10000,)
# Patient 0ddeb08e9c97227853422bd71a2a695e predictions (1, 7) transfer_values (10000,)
# Patient e127111e994be5f79bb0cea52c9d563e predictions (1, 7) transfer_values (10000,)
# Patient 56e0f421b7faddcae027d7feb6dae8cd predictions (1, 7) transfer_values (10000,)
# Patient bfdf6f821031435d9a397afe001ad774 predictions (1, 7) transfer_values (10000,)
# Patient 3b7384f374b73d2bd589ccbf1b651820 predictions (1, 7) transfer_values (10000,)
# Patient 2e26f46f1edc232be164c1fe2712e96a predictions (1, 7) transfer_values (10000,)
# Patient e56b9f25a47a42f4ae4085005c46109c predictions (1, 7) transfer_values (10000,)
# Patient 7b43882369098df840e51421e6059aea predictions (1, 7) transfer_values (10000,)
# Patient eda58f4918c4b506cd156702bf8a56a3 predictions (1, 7) transfer_values (10000,)
# Patient 2a65c8b6d5cc50866de8caa4caabbb6d predictions (1, 7) transfer_values (10000,)
# Patient 85d59b470b927e825937ea3483571c6d predictions (1, 7) transfer_values (10000,)
# Patient 09fdf599084b816247ba38d95b3c9d80 predictions (1, 7) transfer_values (10000,)
# Patient 6e5f12931ef179cc21382a59f5acab86 predictions (1, 7) transfer_values (10000,)
# Patient 16377fe7caf072d882f234dbbff9ef6c predictions (1, 7) transfer_values (10000,)
# Patient 820cc2a44d87d9b3798782f7cc6f2a74 predictions (1, 7) transfer_values (10000,)
# Patient 5f383eb9c3d8ea72ddec7e2e874d577d predictions (1, 7) transfer_values (10000,)
# Patient 2c06f5c66f3c79515b7712605dea4400 predictions (1, 7) transfer_values (10000,)
# Patient c8a82a4e7e76702f5f10ece6508f2bbe predictions (1, 7) transfer_values (10000,)
# Patient b997943f8b95d72ca9a3c36f5c695412 predictions (1, 7) transfer_values (10000,)
# Patient 49b5b3444cf977439600dd06e8dd84ad predictions (1, 7) transfer_values (10000,)
# Patient bb0a8375885408a7adbd7c941098548f predictions (1, 7) transfer_values (10000,)
# Patient 195842462645f0f331147a4c6b129a37 predictions (1, 7) transfer_values (10000,)
# Patient 337e7a428e7342d1e7f53a04247f7ad8 predictions (1, 7) transfer_values (10000,)
# Patient 64a5a866461a3b6006efb0075e04dffe predictions (1, 7) transfer_values (10000,)
# Patient 7577cbd6961b0cab27f88727dcd2d6d3 predictions (1, 7) transfer_values (10000,)
# Patient b17cb533d71d63d548ce47b48b34c23c predictions (1, 7) transfer_values (10000,)
# Patient 6997b392b28529c9ab67add45055fcf7 predictions (1, 7) transfer_values (10000,)
# Patient 7b87e500ff88c264aceb67cf57b32d6d predictions (1, 7) transfer_values (10000,)
# Patient ea7373271a2441b5864df2053c0f5c3e predictions (1, 7) transfer_values (10000,)
# Patient e977737394cee9abb19ad07310aae8eb predictions (1, 7) transfer_values (10000,)
# Patient ac9c16f3f287f0e0b321fb518ac71c75 predictions (1, 7) transfer_values (10000,)
# Patient 817a99e1a60bcf4e37c904d73845ca50 predictions (1, 7) transfer_values (10000,)
# Patient a2f41e283f3c797e85c0b9d63453b365 predictions (1, 7) transfer_values (10000,)
# Patient 48713d11ced3c60a531e6e80258d6425 predictions (1, 7) transfer_values (10000,)
# Patient f39dacd5f134f3f4482094d3f8a0aff1 predictions (1, 7) transfer_values (10000,)
# Patient 9d8bdc380b51812ba82a6040ef207c33 predictions (1, 7) transfer_values (10000,)
# Patient 3170d41d2bc132db30399fca6bc6f376 predictions (1, 7) transfer_values (10000,)
# Patient 9f52323d216f89d300612cfac0122d8b predictions (1, 7) transfer_values (10000,)
# Patient f2e952758095bc50691ab02f724568d2 predictions (1, 7) transfer_values (10000,)
# Patient 90e3b396e1c1343a514eb5890833d3d8 predictions (1, 7) transfer_values (10000,)
# Patient 2b89691a0744504491ef91d711d94918 predictions (1, 7) transfer_values (10000,)
# Patient 56995718fdd0a0549d0e7f11eb307f34 predictions (1, 7) transfer_values (10000,)
# Patient 8264a875a465c029f28110c725fec283 predictions (1, 7) transfer_values (10000,)
# Patient 627836151c555187503dfe472fb15001 predictions (1, 7) transfer_values (10000,)
# Patient 7c8aa548b813dadf972c38e806320179 predictions (1, 7) transfer_values (10000,)
# Patient f5713e8c98ef5378ea678fb8d9192e13 predictions (1, 7) transfer_values (10000,)
# Patient f7a03adba817f2a2249b9dee0586f4be predictions (1, 7) transfer_values (10000,)
# Patient 98bde8f061ae92dd23b0708fdf41381e predictions (1, 7) transfer_values (10000,)
# Patient de881c07adc8d53e52391fac066ccb9f predictions (1, 7) transfer_values (10000,)
# Patient 28649e08938386e3b8eaa4a84baf5982 predictions (1, 7) transfer_values (10000,)
# Patient ac00af80df36484660203d5816d697aa predictions (1, 7) transfer_values (10000,)
# Patient bba773fb9c1c517e23efe05e283b58a2 predictions (1, 7) transfer_values (10000,)
# Patient f467795ce3b50a771085d79ae8d29ecc predictions (1, 7) transfer_values (10000,)
# Patient 59e4e8889ae68a75227b2bd02c1d1b96 predictions (1, 7) transfer_values (10000,)
# Patient 8c5288b86ffcd597f10d639e9948411d predictions (1, 7) transfer_values (10000,)
# Patient 8c9925cf3627cd4742bbc8677f905afc predictions (1, 7) transfer_values (10000,)
# Patient 2615d445b6d3865407d1a4422d25058e predictions (1, 7) transfer_values (10000,)
# Patient e92a2ed80510513497d5252b001cfa3e predictions (1, 7) transfer_values (10000,)
# Patient 662153a685fb4268361bfbaca5e9ca23 predictions (1, 7) transfer_values (10000,)
# Patient 627499714e279203bd1294290f8fc542 predictions (1, 7) transfer_values (10000,)
# Patient 39c404ac6b5852fc8ff00d34bd35294f predictions (1, 7) transfer_values (10000,)
# Patient eb8d5136918d6859ca3cc3abafe369ac predictions (1, 7) transfer_values (10000,)
# Patient 7525f0ec0999007a0bac946e346eba39 predictions (1, 7) transfer_values (10000,)
# Patient 654f2095bace27af870cdfcc66f9717c predictions (1, 7) transfer_values (10000,)
# Patient 2f4645c27f9806daffe7e9d013b4b7eb predictions (1, 7) transfer_values (10000,)
# Patient eefc3f380cc72d6fa830972151df01ad predictions (1, 7) transfer_values (10000,)
# Patient d68bfca920fd548909bd9c7eb5694b9d predictions (1, 7) transfer_values (10000,)
# Patient 013395589c01aa01f8df81d80fb0e2b8 predictions (1, 7) transfer_values (10000,)
# Patient a01074fefbae0234398c365adf970118 predictions (1, 7) transfer_values (10000,)
# Patient 84876a50f52476bcc2a63678257ae8b4 predictions (1, 7) transfer_values (10000,)
# Patient 3938d2274f0576b70fffa9aa68af8874 predictions (1, 7) transfer_values (10000,)
# Patient fa9575f64e6881c6b2730f0e225c9573 predictions (1, 7) transfer_values (10000,)
# Patient 3295f3f392d8e130155c8912b60161b5 predictions (1, 7) transfer_values (10000,)
# Patient 264e5829ef58570c243bfd961098343f predictions (1, 7) transfer_values (10000,)
# Patient 744bb5ab2a706c8070a3f5cd72848ccc predictions (1, 7) transfer_values (10000,)
# Patient 483b89a4ffbbd85acc8b9af5a541dd4d predictions (1, 7) transfer_values (10000,)
# Patient 65dd5d9d5b894e5f0ac3bd6c1384c46a predictions (1, 7) transfer_values (10000,)
# Patient 4b5970e5edc0d8389cabc6bc5d84265f predictions (1, 7) transfer_values (10000,)
# Patient 6f38eb7988753c6a978d0da80dbc014b predictions (1, 7) transfer_values (10000,)
# Patient 3d2b2b0fa9697b298fbbc033481cdcc4 predictions (1, 7) transfer_values (10000,)
# Patient 799c0026d66479f7447ed0df5955f051 predictions (1, 7) transfer_values (10000,)
# Patient 74797049e8df8ed38947fd38840b539d predictions (1, 7) transfer_values (10000,)
# Patient da8fea00d3e921e5d8ab4d90a7f6002f predictions (1, 7) transfer_values (10000,)
# Patient 185bc9d9fa3a58fea90778215c69d35b predictions (1, 7) transfer_values (10000,)
# Patient d73fda3be1180e4465df6fbef8a0648d predictions (1, 7) transfer_values (10000,)
# Patient f43843b39a5be8cd30dab59bd11499ed predictions (1, 7) transfer_values (10000,)
# Patient 4d207541fac845d1a369a160f15d55e6 predictions (1, 7) transfer_values (10000,)
# Patient b1184cbc6dfa46734807211f95f3c998 predictions (1, 7) transfer_values (10000,)
# Patient df75d5a21b4289e8df6e2d0e135ac48f predictions (1, 7) transfer_values (10000,)
# Patient 9f19c381184ba62416025849c464630e predictions (1, 7) transfer_values (10000,)
# Patient 17f5ae9fa49c4e47624f344d29bd03eb predictions (1, 7) transfer_values (10000,)
# Patient 45f4141cfe3f110f9db4e1e113d15684 predictions (1, 7) transfer_values (10000,)
# Patient 933cc0dec1c737d9654820453ce64284 predictions (1, 7) transfer_values (10000,)
# Patient 184c61740244f4ce8fb985af9bb3d8e8 predictions (1, 7) transfer_values (10000,)
# Patient e38789c5eabb3005bfb82a5298055ba0 predictions (1, 7) transfer_values (10000,)
# Patient 322bf0acacba9650fa5656b9613c75c8 predictions (1, 7) transfer_values (10000,)
# Patient 552ef3f04be2073d2cf8a52431576c24 predictions (1, 7) transfer_values (10000,)
# Patient a2d9e657a673798f9ebdfec1b361f93a predictions (1, 7) transfer_values (10000,)
# Patient 220223b46a23db0e2b0577170936845d predictions (1, 7) transfer_values (10000,)
# Patient e10c2b829c39d4a500c09caf04d461a1 predictions (1, 7) transfer_values (10000,)
# Patient 448ce51772879fcd88f61c07b06347b2 predictions (1, 7) transfer_values (10000,)
# Patient f37d1d5c299d4838b294cf82902675b0 predictions (1, 7) transfer_values (10000,)
# Patient 657dc5d2bf8ea210d912dd8320481068 predictions (1, 7) transfer_values (10000,)
# Patient 68f2b9c1fae9180356cb5c4fa95bd30a predictions (1, 7) transfer_values (10000,)
# Patient c187d7be84f64e29e6623c15575f373f predictions (1, 7) transfer_values (10000,)
# Patient f228862e9f9c6ad7993ded4e088c5050 predictions (1, 7) transfer_values (10000,)
# Patient 67ccc2ecd7716e1cab05caaedea99f4b predictions (1, 7) transfer_values (10000,)
# Patient 04fca9fbec0b803326488ade96897f6e predictions (1, 7) transfer_values (10000,)
# Patient dcf75f484b2d2712e5033ba61fd6e2a0 predictions (1, 7) transfer_values (10000,)
# Patient dd571c3949cdae0b59fc0542bb23e06a predictions (1, 7) transfer_values (10000,)
# Patient 570ea80b0dcc08f3e8751a6f4b2b1cd5 predictions (1, 7) transfer_values (10000,)
# Patient 26a2b8d6b94ee16ecf88fb28c57f377e predictions (1, 7) transfer_values (10000,)
# Patient 7b547c5afa0c028b0e20e9a28eaeaa41 predictions (1, 7) transfer_values (10000,)
# Patient 437e42695e7ad0a1cb834e1b3e780516 predictions (1, 7) transfer_values (10000,)
# Patient cca8f8cc51b58df2a4804a7aee8eef8c predictions (1, 7) transfer_values (10000,)
# Patient 6d60c26d7d35ffd967127b380ff01c12 predictions (1, 7) transfer_values (10000,)
# Patient 80600d4a5fee7424d689ba7d0906d50f predictions (1, 7) transfer_values (10000,)
# Patient 78c0a0104c0428e260cbd9e50eb7eea6 predictions (1, 7) transfer_values (10000,)
# Patient ee88217bee233a3bfc971b450e3d8b85 predictions (1, 7) transfer_values (10000,)
# Patient 73280f6a624b3bf7a766c70b31dfc56b predictions (1, 7) transfer_values (10000,)
# Patient d73264d2c4f71ef6bf8593ac55565d93 predictions (1, 7) transfer_values (10000,)
# Patient 6a7f1fd0196a97568f2991c885ac1c0b predictions (1, 7) transfer_values (10000,)
# Patient 60638c0dcee9e5adfcac3b4f57d1366f predictions (1, 7) transfer_values (10000,)
# Patient 9e98136d07b953c3362e0a132c8810b6 predictions (1, 7) transfer_values (10000,)
# Patient c7729e1c348f7d54d743388767c69cb4 predictions (1, 7) transfer_values (10000,)
# Patient eb008af181f3791fdce2376cf4773733 predictions (1, 7) transfer_values (10000,)
# Patient daaf7680aa9a2b519e53b0e38300163d predictions (1, 7) transfer_values (10000,)
# Patient e1e47812eecd80466cf7f5b0160de446 predictions (1, 7) transfer_values (10000,)
# Patient dc66d11755fd073a59743d0df6b62ee2 predictions (1, 7) transfer_values (10000,)
# Patient 81affb342fc98aae0201a6c837cfc3bb predictions (1, 7) transfer_values (10000,)
# Patient 0a0c32c9e08cc2ea76a71649de56be6d predictions (1, 7) transfer_values (10000,)
# Patient 281bb28a077ccfcd40ce4a543a5aea89 predictions (1, 7) transfer_values (10000,)
# Patient 4cc309d81bf3685d7def772862375a2a predictions (1, 7) transfer_values (10000,)
# Patient 0852f5124d69d7f8cd35fa31e1364d29 predictions (1, 7) transfer_values (10000,)
# Patient 2ce2565b9839d8812cf0f9ad80371d3f predictions (1, 7) transfer_values (10000,)
# Patient c98fb8f387c0979531e11de53607de92 predictions (1, 7) transfer_values (10000,)
# Patient fbae4d04285789dfa32124c86586dd09 predictions (1, 7) transfer_values (10000,)
# Patient 66cef72d8428dbba31f2ab01abdaf6ca predictions (1, 7) transfer_values (10000,)
# Patient 14c534e0b7c3176d9106c6215d0aa8c6 predictions (1, 7) transfer_values (10000,)
# Patient 8b6e16b4e1d1400452956578f8eb97c4 predictions (1, 7) transfer_values (10000,)
# Patient 934f01786c3bdf8eeaf7d8411a3a8f82 predictions (1, 7) transfer_values (10000,)
# Patient 310b403db75226a9a44d9a29c18917b7 predictions (1, 7) transfer_values (10000,)
# Patient 2dbb8c6c6ea4ff5c62b34bdf9ea03158 predictions (1, 7) transfer_values (10000,)
# Patient 3dfe8e80106f4136d2933ff72a16035c predictions (1, 7) transfer_values (10000,)
# Patient 49ee28b71e02be4689e3fb0ba2a32c2b predictions (1, 7) transfer_values (10000,)
# Patient 67f7f74220c08faa756b34cb81b203a5 predictions (1, 7) transfer_values (10000,)
# Patient 54d421d543e9e6dc8db10066a5867081 predictions (1, 7) transfer_values (10000,)
# Patient 0c0de3749d4fe175b7a5098b060982a1 predictions (1, 7) transfer_values (10000,)
# Patient a34714908825a61a229bf1457c21ff1f predictions (1, 7) transfer_values (10000,)
# Patient cec6819833f63e96fc3e17e29c0124f8 predictions (1, 7) transfer_values (10000,)
# Patient 5782e6873c666529c6a66421acb043dc predictions (1, 7) transfer_values (10000,)
# Patient 6540e089936a6c9d1f11939e96e6ab18 predictions (1, 7) transfer_values (10000,)
# Patient ef3be197823bfa8c6976ca2621e253d5 predictions (1, 7) transfer_values (10000,)
# Patient f6a2e171a3be579b564cd855985ab9d1 predictions (1, 7) transfer_values (10000,)
# Patient 5861f8f8e35c0713c61e8ab3bc54c905 predictions (1, 7) transfer_values (10000,)
# Patient 9fc639cbbd749117de4980420ae52cf3 predictions (1, 7) transfer_values (10000,)
# Patient 5b642ed9150bac6cbd58a46ed8349afc predictions (1, 7) transfer_values (10000,)
# Patient 31c090cf66ec7bf090801d14d63199b5 predictions (1, 7) transfer_values (10000,)
# Patient cb64ff663195832e0b66a9bb17891954 predictions (1, 7) transfer_values (10000,)
# Patient 42bfcfb0e3965039947bd905b2fc3915 predictions (1, 7) transfer_values (10000,)
# Patient 7a705cc36536145911a2ef9ace7d9930 predictions (1, 7) transfer_values (10000,)
# Patient caddd8f856b110ed9bb52872e003193f predictions (1, 7) transfer_values (10000,)
# Patient b61b1911d3631bee521fcda3a3e568a1 predictions (1, 7) transfer_values (10000,)
# Patient 597643aa6bb96b705eac52e03a307d6d predictions (1, 7) transfer_values (10000,)
# Patient f63f2f63e2619012b4c798fd638c8b8a predictions (1, 7) transfer_values (10000,)
# Patient e9ccf1ce85c39779fafb9ec703c71555 predictions (1, 7) transfer_values (10000,)
# Patient 14afefc82d992018c485949285d20c03 predictions (1, 7) transfer_values (10000,)
# Patient 80a3052f4a1b90fd38fd0def7b79b65c predictions (1, 7) transfer_values (10000,)
# Patient 761aeadb65fb84c8d04978a75b2f684c predictions (1, 7) transfer_values (10000,)
# Patient c0f0eb84e70b19544943bed0ea6bd374 predictions (1, 7) transfer_values (10000,)
# Patient cf0a772e90a14d77d664ce9baedf0e5c predictions (1, 7) transfer_values (10000,)
# Patient fa744c0374ccc6aaf6711f463a9e5bc2 predictions (1, 7) transfer_values (10000,)
# Patient f1a64fda219db48bcfb8ad3823ef9fc1 predictions (1, 7) transfer_values (10000,)
# Patient 1ec082e8e2fa6eb6366b72a13e47b50f predictions (1, 7) transfer_values (10000,)
# Patient baf842dd446ce9d7082efe16d22fb971 predictions (1, 7) transfer_values (10000,)
# Patient d92998a73d4654a442e6d6ba15bbb827 predictions (1, 7) transfer_values (10000,)
# Patient 538600927ec2970552917a29b490b5fd predictions (1, 7) transfer_values (10000,)
# Patient 0c98fcb55e3f36d0c2b6507f62f4c5f1 predictions (1, 7) transfer_values (10000,)
# Patient fe45462987bacc32dbc7126119999392 predictions (1, 7) transfer_values (10000,)
# Patient 356bc45910503ffde017a066581a3798 predictions (1, 7) transfer_values (10000,)
# Patient 0c37613214faddf8701ca41e6d43f56e predictions (1, 7) transfer_values (10000,)
# Patient 0030a160d58723ff36d73f41b170ec21 predictions (1, 7) transfer_values (10000,)
# Patient 6828335aec9aa0d0053ec0949319aa4b predictions (1, 7) transfer_values (10000,)
# Patient 25c369973827571098bdebf2a15c6ef2 predictions (1, 7) transfer_values (10000,)
# Patient 197e035d3aed52b5a2a0de3ee4d5fcea predictions (1, 7) transfer_values (10000,)
# Patient 0708c00f6117ed977bbe1b462b56848c predictions (1, 7) transfer_values (10000,)
# Patient caf9672e7177c141dd3d9c8631af6b8d predictions (1, 7) transfer_values (10000,)
# Patient c68ec9a72b87f4bb7935534182145733 predictions (1, 7) transfer_values (10000,)
# Patient 3a78dcf53effd732bc3880c029154272 predictions (1, 7) transfer_values (10000,)
# Patient c24798432bb6a0d4c80df831b8e09246 predictions (1, 7) transfer_values (10000,)
# Patient ee71210fa398cbb080f6c537a503e806 predictions (1, 7) transfer_values (10000,)
# Patient 666becc9794c25bb8e0e7982be7cb6dc predictions (1, 7) transfer_values (10000,)
# Patient ab5de6c17f4086ba09b7145178d83b45 predictions (1, 7) transfer_values (10000,)
# Patient c2bdfb6ab5192656b397459648221918 predictions (1, 7) transfer_values (10000,)
# Patient 2f4e4a808cfb348d6ddc81de96f72077 predictions (1, 7) transfer_values (10000,)
# Patient cff7e7e9f8cb7b37c109ed6b1f11b783 predictions (1, 7) transfer_values (10000,)
# Patient 2f154a687b94f7b59fec7048cbfb5354 predictions (1, 7) transfer_values (10000,)
# Patient e58b78dc31d80a50285816f4ecd661e3 predictions (1, 7) transfer_values (10000,)
# Patient a76b682e74918492c1f2ca4c13c29885 predictions (1, 7) transfer_values (10000,)
# Patient 7dbc5207b9ec1a1921cc2f03f9b37684 predictions (1, 7) transfer_values (10000,)
# Patient 72609c2be68be9d7c9cde3d0127c05ac predictions (1, 7) transfer_values (10000,)
# Patient 435cd5883a2014f295a8081ea098674b predictions (1, 7) transfer_values (10000,)
# Patient 44cd94d1228f4a70753b5dfc12703414 predictions (1, 7) transfer_values (10000,)
# Patient 8f4c97d428c70831d74660bca08961b9 predictions (1, 7) transfer_values (10000,)
# Patient 750680cce371800ea26576b694b32dc8 predictions (1, 7) transfer_values (10000,)
# Patient 6a145c28d3b722643f547dfcbdf379ae predictions (1, 7) transfer_values (10000,)
# Patient ba162711fc958842582ef1828d37f8e0 predictions (1, 7) transfer_values (10000,)
# Patient 8c22afe3214768d4c585580a2364614d predictions (1, 7) transfer_values (10000,)
# Patient 820245d8b211808bd18e78ff5be16fdb predictions (1, 7) transfer_values (10000,)
# Patient 313efe2e7ecf18a8d484f8b42f30da3e predictions (1, 7) transfer_values (10000,)
# Patient 868b024d9fa388b7ddab12ec1c06af38 predictions (1, 7) transfer_values (10000,)
# Patient 5a2e359e859d0b0d7c159fff87950852 predictions (1, 7) transfer_values (10000,)
# Patient 4f3039ae82f8cc764d1ec21116f54a07 predictions (1, 7) transfer_values (10000,)
# Patient 975f7f3c5bad9e9f0bc31e723fd6f793 predictions (1, 7) transfer_values (10000,)
# Patient 90d6324d7006a3d142ee1884279dcf9b predictions (1, 7) transfer_values (10000,)
# Patient 8918c484841c5d0a532fe146e9da61bd predictions (1, 7) transfer_values (10000,)
# Patient 25a3b616f6cc89e74f6502d65b687972 predictions (1, 7) transfer_values (10000,)
# Patient b1786f35f31c424f6c9e3380c1c51c0b predictions (1, 7) transfer_values (10000,)
# Patient b8dc33b670bb078d10954345c3ffbb3a predictions (1, 7) transfer_values (10000,)
# Patient cb0110b3780d2cf1134221404b82713a predictions (1, 7) transfer_values (10000,)
# Patient bf56e271a2aa37625192954157e9f64d predictions (1, 7) transfer_values (10000,)
# Patient ced4f41abff9290b0638b0a25cd5a26d predictions (1, 7) transfer_values (10000,)
# Patient fb7dfb6aae597d97c2da24179df0fe56 predictions (1, 7) transfer_values (10000,)
# Patient 844032970cb66839f748512acba0be8e predictions (1, 7) transfer_values (10000,)
# Patient 263fa87394ee296e31234364e75d05e2 predictions (1, 7) transfer_values (10000,)
# Patient 4521c94debf37a4dc9f3b70366a21640 predictions (1, 7) transfer_values (10000,)
# Patient afc15e047f3e127871d13e39cde7557d predictions (1, 7) transfer_values (10000,)
# Patient 1b17c83c3b0cb973e41f9121e562d030 predictions (1, 7) transfer_values (10000,)
# Patient 61406252b7c29fbe372adfa953d95199 predictions (1, 7) transfer_values (10000,)
# Patient 1c24a09fa32147d9083ff93f171e1102 predictions (1, 7) transfer_values (10000,)
# Patient a4fa7dd73e3017b97ac6674a10fac216 predictions (1, 7) transfer_values (10000,)
# Patient cf83e9933c484dd9073ed8314794b9f7 predictions (1, 7) transfer_values (10000,)
# Patient cf3034c8828df3c2c23fa697ffde07fa predictions (1, 7) transfer_values (10000,)
# Patient f78944bd1732001a3c62723a8cc19856 predictions (1, 7) transfer_values (10000,)
# Patient 86ff28a92989348192783795a5b442e5 predictions (1, 7) transfer_values (10000,)
# Patient e6d4a747235bfcc1feac759571c8485c predictions (1, 7) transfer_values (10000,)
# Patient 965fbaad39ecdaf8a135f022c8ddaef3 predictions (1, 7) transfer_values (10000,)
# Patient 01de8323fa065a8963533c4a86f2f6c1 predictions (1, 7) transfer_values (10000,)
# Patient 934bc93ae41ee1d98c7c44d483327f8d predictions (1, 7) transfer_values (10000,)
# Patient 2d5cd7c1ee9a74a1244ddd6b55ad0446 predictions (1, 7) transfer_values (10000,)
# Patient daee58dd09c005fe41ca370c2a2fdfa9 predictions (1, 7) transfer_values (10000,)
# Patient b83ce5267f3fd41c7029b4e56724cd08 predictions (1, 7) transfer_values (10000,)
# Patient 8bbad07d91788b97cf894a05a152d291 predictions (1, 7) transfer_values (10000,)
# Patient fd7c0fb3c0e764357aa58e5f047be614 predictions (1, 7) transfer_values (10000,)
# Patient dd281294b34eb6deb76ef9f38169d50e predictions (1, 7) transfer_values (10000,)
# Patient 9560214767e1257dc97c5103a27f1d2c predictions (1, 7) transfer_values (10000,)
# Patient 124e68a78f9c092a2f16f9214e91268f predictions (1, 7) transfer_values (10000,)
# Patient 4131820511c86a5e6b1e7721ab687049 predictions (1, 7) transfer_values (10000,)
# Patient 2dabff545dbfcb9e0efd92220c6aebcc predictions (1, 7) transfer_values (10000,)
# Patient 72b080b50118e9ddb795890eb1f13684 predictions (1, 7) transfer_values (10000,)
# Patient fa7bf17071e3234ab1f350341303b174 predictions (1, 7) transfer_values (10000,)
# Patient 5bf71718aa1bdcada76f0683f8d6b41b predictions (1, 7) transfer_values (10000,)
# Patient a87740afc072074e6c5a2ab787235dde predictions (1, 7) transfer_values (10000,)
# Patient 93a6f37a72f60498986374f57bfc30c4 predictions (1, 7) transfer_values (10000,)
# Patient 55e476ee19742fc09c4ce5e6ebdc13d1 predictions (1, 7) transfer_values (10000,)
# Patient 8f6e50767b3bc4367bfe551b0ed73773 predictions (1, 7) transfer_values (10000,)
# Patient b229a7697c3efcd6ab82f6f19aff8e8b predictions (1, 7) transfer_values (10000,)
# Patient a906cd7c6ad05c27216125485d2b7322 predictions (1, 7) transfer_values (10000,)
# Patient a7eca254c634f5f6e3cd0e508b069f1c predictions (1, 7) transfer_values (10000,)
# Patient 78459ff46c9f3b3fa26be2a467515c7e predictions (1, 7) transfer_values (10000,)
# Patient ccff3e86a50624e30c22d674f3b0f9aa predictions (1, 7) transfer_values (10000,)
# Patient a6b7aa6b98dd87cf75a5e1f707369832 predictions (1, 7) transfer_values (10000,)
# Patient 8c2f9e7025d6070e9f4ab8a65c8e9dbb predictions (1, 7) transfer_values (10000,)
# Patient 4dcd34bd9b10f96453b63d4f55d1fd44 predictions (1, 7) transfer_values (10000,)
# Patient 6c1136ce7fbc5c7b503aa08da6abedd2 predictions (1, 7) transfer_values (10000,)
# Patient 33e0e8629a377e4554b26e60a1007788 predictions (1, 7) transfer_values (10000,)
# Patient ead64f9269f2200e1d439960a1e069b4 predictions (1, 7) transfer_values (10000,)
# Patient c67de8fbbe1e58b464334f93a1dd0447 predictions (1, 7) transfer_values (10000,)
# Patient eef0e41b1a96cf8c55723fa6aa2f3dc6 predictions (1, 7) transfer_values (10000,)
# Patient 6b4837a316e688d0ba125cc1e545d383 predictions (1, 7) transfer_values (10000,)
# Patient 74dca439eb5b6dfa5e33c6d2119630ff predictions (1, 7) transfer_values (10000,)
# Patient e79f52e833ccca893509f0fdeeb26e9f predictions (1, 7) transfer_values (10000,)
# Patient ac4c6d832509d4cee3c7ac93a9227075 predictions (1, 7) transfer_values (10000,)
# Patient 8ee6f423ff988d10f2bb383df98c1b2e predictions (1, 7) transfer_values (10000,)
# Patient 456a7dd28233b398ac83f03c80447b5a predictions (1, 7) transfer_values (10000,)
# Patient 44012bec8f33a785f7844cea8910487d predictions (1, 7) transfer_values (10000,)
# Patient d559c9b1f2be30c82f8dbe4d73d67bd2 predictions (1, 7) transfer_values (10000,)
# Patient 5ade88428e6463fa212d4c287228e8ed predictions (1, 7) transfer_values (10000,)
# Patient e129305f6d074d08cd2de0ebdfeaa576 predictions (1, 7) transfer_values (10000,)
# Patient ee984e8fba88691aac4992fbb14f6e97 predictions (1, 7) transfer_values (10000,)
# Patient d7e5640b52c8e092ec277febc81478da predictions (1, 7) transfer_values (10000,)
# Patient b6687898fe385b68d5ae341419ef3fdd predictions (1, 7) transfer_values (10000,)
# Patient 799b283083f1b6547d558f063b318e78 predictions (1, 7) transfer_values (10000,)
# Patient 24031ba88c58797148475f6d4d5a085b predictions (1, 7) transfer_values (10000,)
# Patient 9a3174ffe867f602ee82c512a01420ee predictions (1, 7) transfer_values (10000,)
# Patient a70fd23bd8d535ffd42259cb91f4c5ca predictions (1, 7) transfer_values (10000,)
# Patient 1b2355e6054759f2f0eb2542ed382b78 predictions (1, 7) transfer_values (10000,)
# Patient a8d308b966048be67f7413daf952ee94 predictions (1, 7) transfer_values (10000,)
# Patient 5818c3be99a83ca8c951ff3434750d6a predictions (1, 7) transfer_values (10000,)
# Patient 4fcf8b00ea7a99162dc70aba253ba669 predictions (1, 7) transfer_values (10000,)
# Patient 08528b8817429d12b7ce2bf444d264f9 predictions (1, 7) transfer_values (10000,)
# Patient 155893351afed6c68893397d19555fd8 predictions (1, 7) transfer_values (10000,)
# Patient 63d907adcf3f12349a0c2c8921d38e89 predictions (1, 7) transfer_values (10000,)
# Patient bedec8e1ad130a08faeec8ed81780d56 predictions (1, 7) transfer_values (10000,)
# Patient a162d204827e4e89a2e5ba81cc53247a predictions (1, 7) transfer_values (10000,)
# Patient 642c43727eee4bda71c0c30bf5cf1a2b predictions (1, 7) transfer_values (10000,)
# Patient 154a79706bcecd0402b913d4bee9eed7 predictions (1, 7) transfer_values (10000,)
# Patient af3657cf479490d027ada92b330f80af predictions (1, 7) transfer_values (10000,)
# Patient 72ed4046708e5607eb0a5703905438ee predictions (1, 7) transfer_values (10000,)
# Patient d9fb9617188fe99bdb464c126d2bd8c0 predictions (1, 7) transfer_values (10000,)
# Patient 51bd5c556c77ecdaf489d8dd9f7a05f1 predictions (1, 7) transfer_values (10000,)
# Patient 8f0c4220a437192a30ae06d82bf78885 predictions (1, 7) transfer_values (10000,)
# Patient 3d521ee3776eefb65953f89c0e1a4f96 predictions (1, 7) transfer_values (10000,)
# Patient bb4b43d0dc4d9d2b61150df6556f6490 predictions (1, 7) transfer_values (10000,)
# Patient 5b412509bc40a3aeb3b5efef1fdfcfc9 predictions (1, 7) transfer_values (10000,)
# Patient 3a3a7a6b3d2a4ea6b1f5bc6ea715eab8 predictions (1, 7) transfer_values (10000,)
# Patient 882107a204c302e27628f85522baea49 predictions (1, 7) transfer_values (10000,)
# Patient 4165b6e956c0e46e94abf7d98f8d8fe2 predictions (1, 7) transfer_values (10000,)
# Patient 9f73628a5e06cfc6723f3ee2ae4b96c4 predictions (1, 7) transfer_values (10000,)
# Patient 89629540f3b3cbc2a18d9919facd34d0 predictions (1, 7) transfer_values (10000,)
# Patient 9b4f0020e407fd7f980f4241fb6ac7ce predictions (1, 7) transfer_values (10000,)
# Patient cceb1ae43615e5f144e31d1d1ebbdf90 predictions (1, 7) transfer_values (10000,)
# Patient fd4c2d4738bc25a5c331dbc101f3323a predictions (1, 7) transfer_values (10000,)
# Patient 5275c7ec0f1d80c829611c378708c05b predictions (1, 7) transfer_values (10000,)
# Patient 338f9c6da34f61091a4c44b074b2f9e3 predictions (1, 7) transfer_values (10000,)
# Patient 2ea91bfe303ec03f9b0b3603333a3de6 predictions (1, 7) transfer_values (10000,)
# Patient eff5b5a7c7245fa8f4661d7e88f8bc7f predictions (1, 7) transfer_values (10000,)
# Patient c3b05094939cc128a4593736f05eadec predictions (1, 7) transfer_values (10000,)
# Patient 089b8f10743e449a0f64f8f311dd8a46 predictions (1, 7) transfer_values (10000,)
# Patient e1f3a01e73d706b7e9c30c0a17a4c0b5 predictions (1, 7) transfer_values (10000,)
# Patient a5cac127acd59505d8f1582b95f80983 predictions (1, 7) transfer_values (10000,)
# Patient 72fd04cf3099b148d9ad361efb988866 predictions (1, 7) transfer_values (10000,)
# Patient d4307a302483bcc04717ca4f565db678 predictions (1, 7) transfer_values (10000,)
# Patient 31136e50b7205e9184227f94cdea0090 predictions (1, 7) transfer_values (10000,)
# Patient 6ae1b284936accdc4101c6daaaa2e0d3 predictions (1, 7) transfer_values (10000,)
# Patient d66d6279f6a55d7263e2700749b4293b predictions (1, 7) transfer_values (10000,)
# Patient ae42429e25ce48034baa3dd527c7810a predictions (1, 7) transfer_values (10000,)
# Patient 68e905099a1c18242aba55c9901eaaae predictions (1, 7) transfer_values (10000,)
# Patient 2ed8eb4430bf40f5405495a5ec22a76d predictions (1, 7) transfer_values (10000,)
# Patient aaeb75b838690ba6ba425f73b9773479 predictions (1, 7) transfer_values (10000,)
# Patient 21bdacdcdb87bf401f34d5d582247c77 predictions (1, 7) transfer_values (10000,)
# Patient 8987df2216ae2ab1a907d52bc9dc540d predictions (1, 7) transfer_values (10000,)
# Patient 1615ace332b9d79be4e0e9fa32c71e9e predictions (1, 7) transfer_values (10000,)
# Patient c6ba816fd9c99c11ceb189ac24d2d2f6 predictions (1, 7) transfer_values (10000,)
# Patient 61c0247462b00b95c4df16edd4486a06 predictions (1, 7) transfer_values (10000,)
# Patient 6cb2908fd789700db727dd96526bc342 predictions (1, 7) transfer_values (10000,)
# Patient a15d4fd19fb32f4858f472962c4bb230 predictions (1, 7) transfer_values (10000,)
# Patient 6799964c08ad5ce7740defcd3bd037a6 predictions (1, 7) transfer_values (10000,)
# Patient 2bf773632e786951d6d594939e6f4713 predictions (1, 7) transfer_values (10000,)
# Patient d7aa27d839b1ecb03dbf011af4bcb092 predictions (1, 7) transfer_values (10000,)
# Patient 05a20caf6ab6df4643644c953f06a5eb predictions (1, 7) transfer_values (10000,)
# Patient 8a8419bb3048294f69a31de36cd35a98 predictions (1, 7) transfer_values (10000,)
# Patient 781cf9cc66e59f4586d9338630b95c1a predictions (1, 7) transfer_values (10000,)
# Patient 7bcecfdddd3bd47e3b36ffb05bbdab60 predictions (1, 7) transfer_values (10000,)
# Patient c2b4ac9d22e601c5d546318874c76f59 predictions (1, 7) transfer_values (10000,)
# Patient a4dc34f2731b62f60c6c390a39fe11b2 predictions (1, 7) transfer_values (10000,)
# Patient b844a9510fc4021d9603cdf24cf0545b predictions (1, 7) transfer_values (10000,)
# Patient 4b19444c570185fc4606e4e29fd1ce1c predictions (1, 7) transfer_values (10000,)
# Patient 6c56e9802fb6346db58bd5daf160f9be predictions (1, 7) transfer_values (10000,)
# Patient 5d801b07718dc9a1ad2bf701523a0f74 predictions (1, 7) transfer_values (10000,)
# Patient 28054f63c5a6ef24e06d8c34258babd6 predictions (1, 7) transfer_values (10000,)
# Patient 4b96e8e085d7ab16c8054654fe586553 predictions (1, 7) transfer_values (10000,)
# Patient 0ee336c585bf7eb1011df476891c5102 predictions (1, 7) transfer_values (10000,)
# Patient 3cdd66bf14f0cff5cb46e95d5867de0d predictions (1, 7) transfer_values (10000,)
# Patient 93b60dbb5cc3fa4c4cc9247cb1143a09 predictions (1, 7) transfer_values (10000,)
# Patient 0890a698c0a6ce5db48b1467011bf8d2 predictions (1, 7) transfer_values (10000,)
# Patient 5c0d992d01e6383d5684b8ac5d7143b1 predictions (1, 7) transfer_values (10000,)
# Patient d36b2cb1cac4b31476c6f86eb1227d3c predictions (1, 7) transfer_values (10000,)
# Patient 385f1f49b0c20563177c36b7470f1c46 predictions (1, 7) transfer_values (10000,)
# Patient e4421d2d5318845c1cccbc6fa308a96e predictions (1, 7) transfer_values (10000,)
# Patient 5a57009fcdea02d30d31a47d2454dc29 predictions (1, 7) transfer_values (10000,)
# Patient fb57fc6377fd37bb5d42756c2736586c predictions (1, 7) transfer_values (10000,)
# Patient 1e33cb12436a64853c1ae9e918633e05 predictions (1, 7) transfer_values (10000,)
# Patient 7f524231183ed193b8f2e3d9cc73c059 predictions (1, 7) transfer_values (10000,)
# Patient 85059119462b510aacb6da54983addcf predictions (1, 7) transfer_values (10000,)
# Patient 34007dd2549af2b82cc1206e550b5100 predictions (1, 7) transfer_values (10000,)
# Patient b2f99ba5baa498246add63b1acf62cd4 predictions (1, 7) transfer_values (10000,)
# Patient fda187bfb1d6a2ecd4abd862c7f7f94c predictions (1, 7) transfer_values (10000,)
# Patient 713d8136c360ad0f37d6e53b61a7891b predictions (1, 7) transfer_values (10000,)
# Patient c1ac4b0949e6e7557f82caf20761322d predictions (1, 7) transfer_values (10000,)
# Patient 02801e3bbcc6966cb115a962012c35df predictions (1, 7) transfer_values (10000,)
# Patient 2bb5f7e8f10e1e39b7f81b5aa98676ea predictions (1, 7) transfer_values (10000,)
# Patient 428e25dfddfe731fc73f4e1739422181 predictions (1, 7) transfer_values (10000,)
# Patient 6af9fecd6807921fa9fe10f0391aa453 predictions (1, 7) transfer_values (10000,)
# Patient ad7e6fe9d036ed070df718f95b212a10 predictions (1, 7) transfer_values (10000,)
# Patient 25c1c4f008e8addc4d386cab58815052 predictions (1, 7) transfer_values (10000,)
# Patient a1b021261acaa7ffedfe15d2c8380de1 predictions (1, 7) transfer_values (10000,)
# Patient 0015ceb851d7251b8f399e39779d1e7d predictions (1, 7) transfer_values (10000,)
# Patient 7b76426f64cb4fbe3d4caa1dcbf47a2f predictions (1, 7) transfer_values (10000,)
# Patient d9ef71a00fd504eac1a6dd104c93ce56 predictions (1, 7) transfer_values (10000,)
# Patient 4348beb99dacd2cbf14983a2c64a00c6 predictions (1, 7) transfer_values (10000,)
# Patient 2e59e2064d391f4b2587a08aff671399 predictions (1, 7) transfer_values (10000,)
# Patient 95edad4544e59e37188dd33db40cecb7 predictions (1, 7) transfer_values (10000,)
# Patient 9ce92cb785c9878389bd5f765a07e1ae predictions (1, 7) transfer_values (10000,)
# Patient c24dfc6534bc563d5aecb1513fea8f7f predictions (1, 7) transfer_values (10000,)
# ...
# Patient 521924ac2f00a62cc63f679de7e599cd predictions (1, 7) transfer_values (10000,)
# Patient 0d2fcf787026fece4e57be167d079383 predictions (1, 7) transfer_values (10000,)
# Patient 081f4a90f24ac33c14b61b97969b7f81 predictions (1, 7) transfer_values (10000,)
# Patient de635c85f320131ee743733bb04e65b9 predictions (1, 7) transfer_values (10000,)
# Patient 9e878fd779fb4d20aaa80db151643442 predictions (1, 7) transfer_values (10000,)
# Patient dc1ecce5e7f8a4be9082cb5650fa62bd predictions (1, 7) transfer_values (10000,)
# Patient 2d81a9e760a07b25903a8c4aeb444eca predictions (1, 7) transfer_values (10000,)
# Patient 5faa4b8d9e86c157b7b16e67f22e7210 predictions (1, 7) transfer_values (10000,)
# Patient 34c0760406297a3c8fd5077fb7cd95b0 predictions (1, 7) transfer_values (10000,)
# Patient 1b7ca8dad5c36feb0a6abf8079173e22 predictions (1, 7) transfer_values (10000,)
# Patient cfbcb16fea277226d6771d8b1966397a predictions (1, 7) transfer_values (10000,)
# Patient f8ecf6be8ae631c6dd694c9638a02b45 predictions (1, 7) transfer_values (10000,)
# Patient 3464083b3e6e7c11d1fba925f0b914cd predictions (1, 7) transfer_values (10000,)
# Patient eba18d04b18084ef64be8f22bb7905ca predictions (1, 7) transfer_values (10000,)
# Patient e5cf847e616cc2fe94816ffa547d2614 predictions (1, 7) transfer_values (10000,)
# Patient bc28807c545959c0e6e2708067201caa predictions (1, 7) transfer_values (10000,)
# Patient 4e9c2cbf385db44b6f5e6618f47318d9 predictions (1, 7) transfer_values (10000,)
# Patient 379d84cd171e6c0e58455c2fd0cf57ef predictions (1, 7) transfer_values (10000,)
# Patient 274a81c75d244187247789bd71de2b3a predictions (1, 7) transfer_values (10000,)
# Patient da821546432756d377777d7f4c41ca2f predictions (1, 7) transfer_values (10000,)
# Patient ef6a37afe024d33b4b1bb2fdee054a59 predictions (1, 7) transfer_values (10000,)
# Patient 573a661e2d784f9385a3b78c9757ddad predictions (1, 7) transfer_values (10000,)
# Patient 624a34fa8fd36847724e749877343847 predictions (1, 7) transfer_values (10000,)
# Patient b887defbf88deb3c6fe4c22405d0a957 predictions (1, 7) transfer_values (10000,)
# Patient 82289d2db2b1e33d68ba6736b21b0e43 predictions (1, 7) transfer_values (10000,)
# Patient 53087ef723e2433ad0b8041e408c6f8c predictions (1, 7) transfer_values (10000,)
# Patient 87cdb87db24528fdb8479220a1854b83 predictions (1, 7) transfer_values (10000,)
# Patient 9d89b32f7dea356b2d35cead7bc94d80 predictions (1, 7) transfer_values (10000,)
# Patient 665ca5ce18dd06722a4c4436a85246b2 predictions (1, 7) transfer_values (10000,)
# Patient 8f28d220d960b67f799479f319373c21 predictions (1, 7) transfer_values (10000,)
# Patient 5572cc61f851b0d10d6fec913ae722b9 predictions (1, 7) transfer_values (10000,)
# Patient 0eafe9b9182b80c6d67015a2062f5143 predictions (1, 7) transfer_values (10000,)
# Patient f243bd277f1876a77a0fb18f9092105a predictions (1, 7) transfer_values (10000,)
# Patient f938f9022abf7f1072fe9df79db7eccd predictions (1, 7) transfer_values (10000,)
# Patient 42dbd247a9e5f710926b7c049a00ff48 predictions (1, 7) transfer_values (10000,)
# Patient 331b14e413e88542855664c845c08c63 predictions (1, 7) transfer_values (10000,)
# Patient 29883252ce0ce3e052ce8cf4932623af predictions (1, 7) transfer_values (10000,)
# Patient 4bf6fb574a2ca2da551609e98a573e54 predictions (1, 7) transfer_values (10000,)
# Patient 199ff05d08ade6e298d37cc542bc3565 predictions (1, 7) transfer_values (10000,)
# Patient bf3dbf9b2379ca92ceaafc1867de0422 predictions (1, 7) transfer_values (10000,)
# Patient 9b259149a750af0c21640624e4be964a predictions (1, 7) transfer_values (10000,)
# Patient 099cec971282b1531d297e5d0d423598 predictions (1, 7) transfer_values (10000,)
# Patient 35b9a3e9871499893f76c8e6c648562c predictions (1, 7) transfer_values (10000,)
# Patient 75aef267ad112a21c870b7e2893aaf8a predictions (1, 7) transfer_values (10000,)
# Patient c690f27c439a58684910d04d6409cd17 predictions (1, 7) transfer_values (10000,)
# Patient 722429bc9cb25d6f4b7a820c14bf2ab1 predictions (1, 7) transfer_values (10000,)
# Patient 84a6c418d57bfc5214639012998356d4 predictions (1, 7) transfer_values (10000,)
# Patient 66b7666912e1d469cd9817a1cade694c predictions (1, 7) transfer_values (10000,)
# Patient 3187b6cf14ed2cbe611b01da5e161f21 predictions (1, 7) transfer_values (10000,)
# Patient 592c2481f17d6a2cecfe7bbb6a27722c predictions (1, 7) transfer_values (10000,)
# Patient b921bb8f821ccab27ab69ea94b8149a7 predictions (1, 7) transfer_values (10000,)
# Patient bcb416e94f3505c120a54dbfc0d5a234 predictions (1, 7) transfer_values (10000,)
# Patient 08643d7b9ce18405fb63f63dda258e76 predictions (1, 7) transfer_values (10000,)
# Patient 39ebb8121ea6faec0405a4e8db883b55 predictions (1, 7) transfer_values (10000,)
# Patient 6f43af3f636f37b9695b58378f9265cc predictions (1, 7) transfer_values (10000,)
# Patient 08acb3440eb23385724d006403feb585 predictions (1, 7) transfer_values (10000,)
# Patient 38d89e67d2ea7e2ab023c10f5f19f716 predictions (1, 7) transfer_values (10000,)
# Patient 28352e12fe29361dfd9613ed2e729192 predictions (1, 7) transfer_values (10000,)
# Patient 243e69389ae5738d3f89386b0efddbcd predictions (1, 7) transfer_values (10000,)
# Patient 7239b3a904f39b25c4e303c10a24621a predictions (1, 7) transfer_values (10000,)
# Patient e6b3e750c6c7a70ca512d77defcfe615 predictions (1, 7) transfer_values (10000,)
# Patient 2ed2ec628e6ad9d0aa8c2a9b7bf4c4ce predictions (1, 7) transfer_values (10000,)
# Patient 5a06cb92ba004e2265ab087b5b09e33a predictions (1, 7) transfer_values (10000,)
# Patient 487cc9003c99fa95e9a9e201d396992c predictions (1, 7) transfer_values (10000,)
# Patient 3c73f5597780b7312b380373fb897f40 predictions (1, 7) transfer_values (10000,)
# Patient e8eb842ee04bbad407f85fe671f24d4f predictions (1, 7) transfer_values (10000,)
# Patient 7bd3565827be855caf938e72b3a7880a predictions (1, 7) transfer_values (10000,)
# Patient 66fb40934f0be4b301fe27db7fb62299 predictions (1, 7) transfer_values (10000,)
# Patient fbe0c3d6e4a50ca1c1bd3101515d0ab4 predictions (1, 7) transfer_values (10000,)
# Patient a590753c175011e42bf17b90e3aec3b0 predictions (1, 7) transfer_values (10000,)
# Patient e709901da9ba15a95d4a29906edc01dd predictions (1, 7) transfer_values (10000,)
# Patient 436fd6ccfc92afc44c7d3ccfe26b6129 predictions (1, 7) transfer_values (10000,)
# Patient 55c01868f1d9c37fa3f174dc3c0d44e8 predictions (1, 7) transfer_values (10000,)
# Patient 37dbe298bb4e0199625689cc35d390bb predictions (1, 7) transfer_values (10000,)
# Patient d0c1c175814c610bc333080152a605f7 predictions (1, 7) transfer_values (10000,)
# Patient 2922aac33a190fd3939de337fe3f0a34 predictions (1, 7) transfer_values (10000,)
# Patient c645eb8b7b7225457e61cf511a8e46e5 predictions (1, 7) transfer_values (10000,)
# Patient 797d6bffdecfc88e990e820dc5771a0b predictions (1, 7) transfer_values (10000,)
# Patient 9e922147900b3984c9345bdda573e882 predictions (1, 7) transfer_values (10000,)
# Patient 04e5d435fa01b0958e3274be73312cac predictions (1, 7) transfer_values (10000,)
# Patient 7180c83eb184d5c9dfcbda228ab91213 predictions (1, 7) transfer_values (10000,)
# Patient 0fb1b54da1e66c60a57db9c52f945e25 predictions (1, 7) transfer_values (10000,)
# Patient cf34926681dbf1129cb0a629fb72681b predictions (1, 7) transfer_values (10000,)
# Patient af7420c5b1c47763ecb5f6e286517b2e predictions (1, 7) transfer_values (10000,)
# Patient c05acf3bd59f5570783138c01b737c3d predictions (1, 7) transfer_values (10000,)
# Patient b947a27711c94dda2d13e7410285cc0c predictions (1, 7) transfer_values (10000,)
# Patient 2885e3af725bc58dc1522d4bfb24bb2b predictions (1, 7) transfer_values (10000,)
# Patient e63f43056330bc418a11208aa3a9e7f0 predictions (1, 7) transfer_values (10000,)
# Patient 1ff6e2a80eb74396e09460c61ae69fb0 predictions (1, 7) transfer_values (10000,)
# Patient 2117642550461db380a019bbd10a95e5 predictions (1, 7) transfer_values (10000,)
# Patient ac68eb0a3db3de247c26909db4c10569 predictions (1, 7) transfer_values (10000,)
# Patient 968808e60982c76366088b4db7254671 predictions (1, 7) transfer_values (10000,)
# Patient 7050f8141e92fa42fd9c471a8b2f50ce predictions (1, 7) transfer_values (10000,)
# Patient cb94c3f894fc93c1ec0eb436c8564ed3 predictions (1, 7) transfer_values (10000,)
# Patient 493641ef65ee95fe994d4789aec1db3b predictions (1, 7) transfer_values (10000,)
# Patient 4fb3d996e87999e0dfa0009a3e5f0fbc predictions (1, 7) transfer_values (10000,)
# Patient fdf73dcce35167f3ed952a58f5a6f738 predictions (1, 7) transfer_values (10000,)
# Patient a7411bdc623413af46a30bd9d2c41066 predictions (1, 7) transfer_values (10000,)
# Patient fb7ae70f05b6441ac4ea7187ce7c45f7 predictions (1, 7) transfer_values (10000,)
# Patient 14f713c1ef037f6c531cffdff0e5fb2c predictions (1, 7) transfer_values (10000,)
# Patient 404e5dd2b032a223282f5a5e73c05418 predictions (1, 7) transfer_values (10000,)
# Patient d3bc6721c1b0830137515e9c0c31612b predictions (1, 7) transfer_values (10000,)
# Patient c0625c79ef5b37e293b5753d20b00c89 predictions (1, 7) transfer_values (10000,)
# Patient b635cda3e75b4b7238c18c6a5f1858f6 predictions (1, 7) transfer_values (10000,)
# Patient 43fecc8947e4fbb47968dc8ef7d8f4ec predictions (1, 7) transfer_values (10000,)
# Patient c98675ecb5bdc7eb35c69d730da05df1 predictions (1, 7) transfer_values (10000,)
# Patient 46199ffd681fd429aca3823c76f1034d predictions (1, 7) transfer_values (10000,)
# Patient 8f0d9699a15acef00da458eceaf0c846 predictions (1, 7) transfer_values (10000,)
# Patient 839502f9ff68fd778b435255690f3061 predictions (1, 7) transfer_values (10000,)
# Patient 1a41350d4bbd74b7e0e28239cefa84c2 predictions (1, 7) transfer_values (10000,)
# Patient caf5e9cd994c3c90727d274dd790133a predictions (1, 7) transfer_values (10000,)
# Patient e2b7fe7fbb002029640c0e65e3051888 predictions (1, 7) transfer_values (10000,)
# Patient 4209cb1fbce28cd68da900eb9bef26b3 predictions (1, 7) transfer_values (10000,)
# Patient 991a2fe88aeb9ef23bb011e3843c9105 predictions (1, 7) transfer_values (10000,)
# Patient dd5764803d51c71a27707d9db8c84aac predictions (1, 7) transfer_values (10000,)
# Patient 27e9f8b51aeee67918221f2df98e9cbc predictions (1, 7) transfer_values (10000,)
# Patient eaf753dc137e12fd06e96d27f3111043 predictions (1, 7) transfer_values (10000,)
# Patient 57822feb6186b788c4e1877123428454 predictions (1, 7) transfer_values (10000,)
# Patient ad5f3a8ee73c1ff4cf401746be3bd493 predictions (1, 7) transfer_values (10000,)
# Patient e3a9a6f8d21c6c459728066bcf18c615 predictions (1, 7) transfer_values (10000,)
# Patient 9703fd051751879432975535663150da predictions (1, 7) transfer_values (10000,)
# Patient bbf958c2331a553d5699a1369b7f2bbf predictions (1, 7) transfer_values (10000,)
# Patient 65073aadb60e398d8db1806f5ea2a082 predictions (1, 7) transfer_values (10000,)
# Patient 5c99ab7172afa78312fe73a3c0dd342f predictions (1, 7) transfer_values (10000,)
# Patient a187b24f9827de759fb86a84e9b2e544 predictions (1, 7) transfer_values (10000,)
# Patient cd104ad99d5b939b6bdd28b154e28085 predictions (1, 7) transfer_values (10000,)
# Patient 2fced53a125854edb9284ff12795caf8 predictions (1, 7) transfer_values (10000,)
# Patient d244870d213a21efa86e86c951d8c9a2 predictions (1, 7) transfer_values (10000,)
# Patient 2a20e4a4e6411f72374fdffebabfc235 predictions (1, 7) transfer_values (10000,)
# Patient 96fdfdfc4417d5bf8e6750edbac8ff90 predictions (1, 7) transfer_values (10000,)
# Patient 916ab7b22affc5651abfc9aae01bb355 predictions (1, 7) transfer_values (10000,)
# Patient d2eecd9f13a6d474338045d0c91cffbd predictions (1, 7) transfer_values (10000,)
# Patient b022a1d30d62ef2c1f0902f1a047a845 predictions (1, 7) transfer_values (10000,)
# Patient 80588b9231bb4fb7e1cddc9321d12e76 predictions (1, 7) transfer_values (10000,)
# Patient be4285333fb2d56f78ca867d97eee308 predictions (1, 7) transfer_values (10000,)
# Patient f88ed45f3436cb30e494409dae76df5d predictions (1, 7) transfer_values (10000,)
# Patient 721949894f5309ed4975a67419230a3c predictions (1, 7) transfer_values (10000,)
# Patient 763ce10dfdd4662f15de3f5931d5534b predictions (1, 7) transfer_values (10000,)
# Patient 0482c444ac838adc5aa00d1064c976c1 predictions (1, 7) transfer_values (10000,)
# Patient 2d8152c603e6c49593578bde8e388860 predictions (1, 7) transfer_values (10000,)
# Patient dcde02d4757bb845376fa6dbb0351df6 predictions (1, 7) transfer_values (10000,)
# Patient 90409f7fcfec3581033559f8340e48a9 predictions (1, 7) transfer_values (10000,)
# Patient 463b67fefdde16ba3c4a4258de1f38e3 predictions (1, 7) transfer_values (10000,)
# Patient a6efbb642c60022fe194da17d71a7fb3 predictions (1, 7) transfer_values (10000,)
# Patient caf38dcf62fe3a05fac40055920d7058 predictions (1, 7) transfer_values (10000,)
# Patient 1427be78bcf4aba96c5054b697be9b5b predictions (1, 7) transfer_values (10000,)
# Patient 502d4601458807bf0089e6fd07825357 predictions (1, 7) transfer_values (10000,)
# Patient bd702368c252929cf701ad56ce64b6e1 predictions (1, 7) transfer_values (10000,)
# Patient cbf5f53f3648de7d1324257caa40bb90 predictions (1, 7) transfer_values (10000,)
# Patient 0acbebb8d463b4b9ca88cf38431aac69 predictions (1, 7) transfer_values (10000,)
# Patient 91d0606b85ab7dbc7bab718c1312f2df predictions (1, 7) transfer_values (10000,)
# Patient 8298238a27be6111214a9bc711608181 predictions (1, 7) transfer_values (10000,)
# Patient f69c80f898c9dfd8d3595b7ca7b8c66c predictions (1, 7) transfer_values (10000,)
# Patient 2fc3d8ef26fc7aafad44d5034673dd4c predictions (1, 7) transfer_values (10000,)
# Patient 58bac12ccb44919bbd64271f38ee0584 predictions (1, 7) transfer_values (10000,)
# Patient 1748ad43b222be66f3e5ae4bd70c02ac predictions (1, 7) transfer_values (10000,)
# Patient e43afa905c8e279f818b2d5104f6762b predictions (1, 7) transfer_values (10000,)
# Patient fe26fd2bb25112b3c2ca93eb8e34f8ed predictions (1, 7) transfer_values (10000,)
# Patient 2a549c66f24af964de6f25165c55e331 predictions (1, 7) transfer_values (10000,)
# Patient 1c05dea5723caf192af34ceb5804468f predictions (1, 7) transfer_values (10000,)
# Patient bbe21f027a1df4b07016b474b48d3f65 predictions (1, 7) transfer_values (10000,)
# Patient b3f57de0b4ad4dfae87698ef8fc67e23 predictions (1, 7) transfer_values (10000,)
# Patient 8815efa67adb15b2f8cfd49ec992f48e predictions (1, 7) transfer_values (10000,)
# Patient 28a9b77a9113ce491433d3ea47fa8fc9 predictions (1, 7) transfer_values (10000,)
# Patient 064366faa1a83fdcb18b2538f1717290 predictions (1, 7) transfer_values (10000,)
# Patient 54056288ab97cebc4b0ea33c23f47ff6 predictions (1, 7) transfer_values (10000,)
# Patient 39dc5f09d7b8eeda7f2f02c86f53247d predictions (1, 7) transfer_values (10000,)
# Patient b5de57869d863bdc1b84b0194e79a9d3 predictions (1, 7) transfer_values (10000,)
# Patient e1c92d3f85a37bd8bb963345b6d66e03 predictions (1, 7) transfer_values (10000,)
# Patient d00ee8f03fb00562b2db35e90536ffc1 predictions (1, 7) transfer_values (10000,)
# Patient 33da5fb759223c316e8cec9d884d1584 predictions (1, 7) transfer_values (10000,)
# Patient 733205c5d0bbf19f5c761e0c023bf9a0 predictions (1, 7) transfer_values (10000,)
# Patient 04a52f49cdbfb8b99789b9e93f1ad319 predictions (1, 7) transfer_values (10000,)
# Patient 76f36ea4858c572b425eb915e1b27c8d predictions (1, 7) transfer_values (10000,)
# Patient 1c498f306808952739e7a3a3a2439d1e predictions (1, 7) transfer_values (10000,)
# Patient 8e0624a689e8e02dbae149771f51f8ca predictions (1, 7) transfer_values (10000,)
# Patient 0257df465d9e4150adef13303433ff1e predictions (1, 7) transfer_values (10000,)
# Patient 6675d3cc20585f44d4c45746cb1002d4 predictions (1, 7) transfer_values (10000,)
# Patient e2a7eaebd0830061e77690aa48f11936 predictions (1, 7) transfer_values (10000,)
# Patient 07bca4290a2530091ce1d5f200d9d526 predictions (1, 7) transfer_values (10000,)
# Patient 51fbac477a3639f983904fc4d42b8c15 predictions (1, 7) transfer_values (10000,)
# Patient 6fd3af9174242c1b393fe4ba515e7a26 predictions (1, 7) transfer_values (10000,)
# Patient 8c7b03ed7f61c7faa5a26e126d769404 predictions (1, 7) transfer_values (10000,)
# Patient 56462ba8833fc842d16be7e311214404 predictions (1, 7) transfer_values (10000,)
# Patient 2eb8aedb5274414e05041b7be65db3e3 predictions (1, 7) transfer_values (10000,)
# Patient 55baceb599dc8aefe4b13c131d0531df predictions (1, 7) transfer_values (10000,)
# Patient c1673993c070080c1d65aca6799c66f8 predictions (1, 7) transfer_values (10000,)
# Patient 7df28e2253be3490208ba9a9f470ea1d predictions (1, 7) transfer_values (10000,)

# %%
x = np.array([inputs[keys][0]for keys in inputs.keys()])
y = (np.array([inputs[keys][1] for keys in inputs.keys()])).reshape(-1,1)
trn_x, val_x, trn_y, val_y = cross_validation.train_test_split(x, y, random_state=42, stratify=y, test_size=0.20)

# %%
clf = train_xgboost(trn_x, val_x, trn_y, val_y)
# Out:
# [0]	validation_0-logloss:0.692241
# Will train until validation_0-logloss hasn't improved in 50 rounds.
# [1]	validation_0-logloss:0.6913
# [2]	validation_0-logloss:0.690383
# [3]	validation_0-logloss:0.689491
# [4]	validation_0-logloss:0.688752
# [5]	validation_0-logloss:0.687927
# [6]	validation_0-logloss:0.687097
# [7]	validation_0-logloss:0.686278
# [8]	validation_0-logloss:0.685539
# [9]	validation_0-logloss:0.684703
# [10]	validation_0-logloss:0.68391
# [11]	validation_0-logloss:0.683351
# [12]	validation_0-logloss:0.682534
# [13]	validation_0-logloss:0.681767
# [14]	validation_0-logloss:0.681131
# [15]	validation_0-logloss:0.680269
# [16]	validation_0-logloss:0.679379
# [17]	validation_0-logloss:0.678516
# [18]	validation_0-logloss:0.677716
# [19]	validation_0-logloss:0.677035
# [20]	validation_0-logloss:0.676366
# [21]	validation_0-logloss:0.675585
# [22]	validation_0-logloss:0.674812
# [23]	validation_0-logloss:0.674169
# [24]	validation_0-logloss:0.673348
# [25]	validation_0-logloss:0.672692
# [26]	validation_0-logloss:0.671941
# [27]	validation_0-logloss:0.671246
# [28]	validation_0-logloss:0.670574
# [29]	validation_0-logloss:0.669868
# [30]	validation_0-logloss:0.669044
# [31]	validation_0-logloss:0.668472
# [32]	validation_0-logloss:0.667763
# [33]	validation_0-logloss:0.667119
# [34]	validation_0-logloss:0.66649
# [35]	validation_0-logloss:0.665788
# [36]	validation_0-logloss:0.665287
# [37]	validation_0-logloss:0.664573
# [38]	validation_0-logloss:0.663934
# [39]	validation_0-logloss:0.663182
# [40]	validation_0-logloss:0.662573
# [41]	validation_0-logloss:0.661934
# [42]	validation_0-logloss:0.661222
# [43]	validation_0-logloss:0.660622
# [44]	validation_0-logloss:0.660037
# [45]	validation_0-logloss:0.659464
# [46]	validation_0-logloss:0.658919
# [47]	validation_0-logloss:0.658261
# [48]	validation_0-logloss:0.657712
# [49]	validation_0-logloss:0.656978
# [50]	validation_0-logloss:0.656498
# [51]	validation_0-logloss:0.655795
# [52]	validation_0-logloss:0.655167
# [53]	validation_0-logloss:0.654659
# [54]	validation_0-logloss:0.653898
# [55]	validation_0-logloss:0.653294
# [56]	validation_0-logloss:0.6526
# [57]	validation_0-logloss:0.652008
# [58]	validation_0-logloss:0.651411
# [59]	validation_0-logloss:0.651074
# [60]	validation_0-logloss:0.650543
# [61]	validation_0-logloss:0.649907
# [62]	validation_0-logloss:0.649457
# [63]	validation_0-logloss:0.648825
# [64]	validation_0-logloss:0.648275
# [65]	validation_0-logloss:0.64774
# [66]	validation_0-logloss:0.647153
# [67]	validation_0-logloss:0.646687
# [68]	validation_0-logloss:0.646262
# [69]	validation_0-logloss:0.645737
# [70]	validation_0-logloss:0.64512
# [71]	validation_0-logloss:0.644692
# [72]	validation_0-logloss:0.644077
# [73]	validation_0-logloss:0.64354
# [74]	validation_0-logloss:0.643068
# [75]	validation_0-logloss:0.64255
# [76]	validation_0-logloss:0.642
# [77]	validation_0-logloss:0.641502
# [78]	validation_0-logloss:0.641045
# [79]	validation_0-logloss:0.640587
# [80]	validation_0-logloss:0.640044
# [81]	validation_0-logloss:0.63947
# [82]	validation_0-logloss:0.639023
# [83]	validation_0-logloss:0.638633
# [84]	validation_0-logloss:0.638083
# [85]	validation_0-logloss:0.637735
# [86]	validation_0-logloss:0.637272
# [87]	validation_0-logloss:0.636818
# [88]	validation_0-logloss:0.636246
# [89]	validation_0-logloss:0.635792
# [90]	validation_0-logloss:0.635487
# [91]	validation_0-logloss:0.635149
# [92]	validation_0-logloss:0.63462
# [93]	validation_0-logloss:0.634158
# [94]	validation_0-logloss:0.633793
# [95]	validation_0-logloss:0.633466
# [96]	validation_0-logloss:0.633125
# [97]	validation_0-logloss:0.632598
# [98]	validation_0-logloss:0.632074
# [99]	validation_0-logloss:0.631829
# [100]	validation_0-logloss:0.631309
# [101]	validation_0-logloss:0.630883
# [102]	validation_0-logloss:0.63038
# [103]	validation_0-logloss:0.630022
# [104]	validation_0-logloss:0.629793
# [105]	validation_0-logloss:0.629395
# [106]	validation_0-logloss:0.629182
# [107]	validation_0-logloss:0.628795
# [108]	validation_0-logloss:0.628513
# [109]	validation_0-logloss:0.628176
# [110]	validation_0-logloss:0.627996
# [111]	validation_0-logloss:0.627634
# [112]	validation_0-logloss:0.6273
# [113]	validation_0-logloss:0.627111
# [114]	validation_0-logloss:0.626833
# [115]	validation_0-logloss:0.626382
# [116]	validation_0-logloss:0.625794
# [117]	validation_0-logloss:0.625335
# [118]	validation_0-logloss:0.624959
# [119]	validation_0-logloss:0.624576
# [120]	validation_0-logloss:0.624216
# [121]	validation_0-logloss:0.623963
# [122]	validation_0-logloss:0.623577
# [123]	validation_0-logloss:0.623261
# [124]	validation_0-logloss:0.623001
# [125]	validation_0-logloss:0.622646
# [126]	validation_0-logloss:0.62229
# [127]	validation_0-logloss:0.621888
# [128]	validation_0-logloss:0.621614
# [129]	validation_0-logloss:0.621305
# [130]	validation_0-logloss:0.621021
# [131]	validation_0-logloss:0.620535
# [132]	validation_0-logloss:0.62013
# [133]	validation_0-logloss:0.619745
# [134]	validation_0-logloss:0.619505
# [135]	validation_0-logloss:0.619109
# [136]	validation_0-logloss:0.618642
# [137]	validation_0-logloss:0.618294
# [138]	validation_0-logloss:0.618039
# [139]	validation_0-logloss:0.617696
# [140]	validation_0-logloss:0.617435
# [141]	validation_0-logloss:0.617204
# [142]	validation_0-logloss:0.616835
# [143]	validation_0-logloss:0.616474
# [144]	validation_0-logloss:0.616191
# [145]	validation_0-logloss:0.615788
# [146]	validation_0-logloss:0.61563
# [147]	validation_0-logloss:0.615453
# [148]	validation_0-logloss:0.615032
# [149]	validation_0-logloss:0.614808
# [150]	validation_0-logloss:0.614627
# [151]	validation_0-logloss:0.614366
# [152]	validation_0-logloss:0.613922
# [153]	validation_0-logloss:0.613625
# [154]	validation_0-logloss:0.613387
# [155]	validation_0-logloss:0.613053
# [156]	validation_0-logloss:0.612663
# [157]	validation_0-logloss:0.61238
# [158]	validation_0-logloss:0.612234
# [159]	validation_0-logloss:0.611967
# [160]	validation_0-logloss:0.61163
# [161]	validation_0-logloss:0.611362
# [162]	validation_0-logloss:0.611059
# [163]	validation_0-logloss:0.610792
# [164]	validation_0-logloss:0.610334
# [165]	validation_0-logloss:0.610068
# [166]	validation_0-logloss:0.609967
# [167]	validation_0-logloss:0.609745
# [168]	validation_0-logloss:0.60941
# [169]	validation_0-logloss:0.609028
# [170]	validation_0-logloss:0.608617
# [171]	validation_0-logloss:0.608365
# [172]	validation_0-logloss:0.608122
# [173]	validation_0-logloss:0.607889
# [174]	validation_0-logloss:0.607591
# [175]	validation_0-logloss:0.607154
# [176]	validation_0-logloss:0.606822
# [177]	validation_0-logloss:0.60658
# [178]	validation_0-logloss:0.606343
# [179]	validation_0-logloss:0.606168
# [180]	validation_0-logloss:0.605728
# [181]	validation_0-logloss:0.605646
# [182]	validation_0-logloss:0.605307
# [183]	validation_0-logloss:0.604973
# [184]	validation_0-logloss:0.604612
# [185]	validation_0-logloss:0.604367
# [186]	validation_0-logloss:0.604104
# [187]	validation_0-logloss:0.603739
# [188]	validation_0-logloss:0.603565
# [189]	validation_0-logloss:0.603289
# [190]	validation_0-logloss:0.602921
# [191]	validation_0-logloss:0.602808
# [192]	validation_0-logloss:0.602616
# [193]	validation_0-logloss:0.602302
# [194]	validation_0-logloss:0.602017
# [195]	validation_0-logloss:0.60179
# [196]	validation_0-logloss:0.60175
# [197]	validation_0-logloss:0.601562
# [198]	validation_0-logloss:0.601298
# [199]	validation_0-logloss:0.601126
# [200]	validation_0-logloss:0.600844
# [201]	validation_0-logloss:0.600678
# [202]	validation_0-logloss:0.600332
# [203]	validation_0-logloss:0.600141
# [204]	validation_0-logloss:0.599723
# [205]	validation_0-logloss:0.599512
# [206]	validation_0-logloss:0.599362
# [207]	validation_0-logloss:0.599201
# [208]	validation_0-logloss:0.599147
# [209]	validation_0-logloss:0.59876
# [210]	validation_0-logloss:0.598508
# [211]	validation_0-logloss:0.598277
# [212]	validation_0-logloss:0.598021
# [213]	validation_0-logloss:0.597851
# [214]	validation_0-logloss:0.597661
# [215]	validation_0-logloss:0.597396
# [216]	validation_0-logloss:0.597134
# [217]	validation_0-logloss:0.596915
# [218]	validation_0-logloss:0.596677
# [219]	validation_0-logloss:0.596664
# [220]	validation_0-logloss:0.59642
# [221]	validation_0-logloss:0.596217
# [222]	validation_0-logloss:0.596118
# [223]	validation_0-logloss:0.595919
# [224]	validation_0-logloss:0.595666
# [225]	validation_0-logloss:0.59561
# [226]	validation_0-logloss:0.595331
# [227]	validation_0-logloss:0.595082
# [228]	validation_0-logloss:0.594873
# [229]	validation_0-logloss:0.594752
# [230]	validation_0-logloss:0.594498
# [231]	validation_0-logloss:0.594296
# [232]	validation_0-logloss:0.594209
# [233]	validation_0-logloss:0.593986
# [234]	validation_0-logloss:0.593775
# [235]	validation_0-logloss:0.593519
# [236]	validation_0-logloss:0.593385
# [237]	validation_0-logloss:0.593272
# [238]	validation_0-logloss:0.592946
# [239]	validation_0-logloss:0.592992
# [240]	validation_0-logloss:0.592863
# [241]	validation_0-logloss:0.592648
# [242]	validation_0-logloss:0.592598
# [243]	validation_0-logloss:0.592498
# [244]	validation_0-logloss:0.592413
# [245]	validation_0-logloss:0.592226
# [246]	validation_0-logloss:0.592024
# [247]	validation_0-logloss:0.591817
# [248]	validation_0-logloss:0.591572
# [249]	validation_0-logloss:0.5916
# [250]	validation_0-logloss:0.591477
# [251]	validation_0-logloss:0.591396
# [252]	validation_0-logloss:0.59124
# [253]	validation_0-logloss:0.591161
# [254]	validation_0-logloss:0.59099
# [255]	validation_0-logloss:0.590917
# [256]	validation_0-logloss:0.590736
# [257]	validation_0-logloss:0.590501
# [258]	validation_0-logloss:0.590221
# [259]	validation_0-logloss:0.590061
# [260]	validation_0-logloss:0.589821
# [261]	validation_0-logloss:0.589648
# [262]	validation_0-logloss:0.589466
# [263]	validation_0-logloss:0.589426
# [264]	validation_0-logloss:0.589425
# [265]	validation_0-logloss:0.589222
# [266]	validation_0-logloss:0.588943
# [267]	validation_0-logloss:0.588761
# [268]	validation_0-logloss:0.588478
# [269]	validation_0-logloss:0.588474
# [270]	validation_0-logloss:0.588361
# [271]	validation_0-logloss:0.588101
# [272]	validation_0-logloss:0.587916
# [273]	validation_0-logloss:0.58766
# [274]	validation_0-logloss:0.5877
# [275]	validation_0-logloss:0.587677
# [276]	validation_0-logloss:0.587497
# [277]	validation_0-logloss:0.58741
# [278]	validation_0-logloss:0.587223
# [279]	validation_0-logloss:0.587154
# [280]	validation_0-logloss:0.587118
# [281]	validation_0-logloss:0.587037
# [282]	validation_0-logloss:0.586904
# [283]	validation_0-logloss:0.586936
# [284]	validation_0-logloss:0.586802
# [285]	validation_0-logloss:0.586587
# [286]	validation_0-logloss:0.58656
# [287]	validation_0-logloss:0.58638
# [288]	validation_0-logloss:0.586404
# [289]	validation_0-logloss:0.586267
# [290]	validation_0-logloss:0.586161
# [291]	validation_0-logloss:0.586059
# [292]	validation_0-logloss:0.586001
# [293]	validation_0-logloss:0.58594
# [294]	validation_0-logloss:0.585775
# [295]	validation_0-logloss:0.585542
# [296]	validation_0-logloss:0.585469
# [297]	validation_0-logloss:0.585402
# [298]	validation_0-logloss:0.585424
# [299]	validation_0-logloss:0.585237
# [300]	validation_0-logloss:0.585015
# [301]	validation_0-logloss:0.585061
# [302]	validation_0-logloss:0.585011
# [303]	validation_0-logloss:0.584709
# [304]	validation_0-logloss:0.584546
# [305]	validation_0-logloss:0.58458
# [306]	validation_0-logloss:0.584574
# [307]	validation_0-logloss:0.584458
# [308]	validation_0-logloss:0.584142
# [309]	validation_0-logloss:0.584091
# [310]	validation_0-logloss:0.583933
# [311]	validation_0-logloss:0.583856
# [312]	validation_0-logloss:0.583761
# [313]	validation_0-logloss:0.58361
# [314]	validation_0-logloss:0.583495
# [315]	validation_0-logloss:0.583258
# [316]	validation_0-logloss:0.583154
# [317]	validation_0-logloss:0.583106
# [318]	validation_0-logloss:0.582929
# [319]	validation_0-logloss:0.582873
# [320]	validation_0-logloss:0.582766
# [321]	validation_0-logloss:0.582634
# [322]	validation_0-logloss:0.582513
# [323]	validation_0-logloss:0.582491
# [324]	validation_0-logloss:0.582281
# [325]	validation_0-logloss:0.582181
# [326]	validation_0-logloss:0.582168
# [327]	validation_0-logloss:0.582036
# [328]	validation_0-logloss:0.581926
# [329]	validation_0-logloss:0.581889
# [330]	validation_0-logloss:0.581655
# [331]	validation_0-logloss:0.581487
# [332]	validation_0-logloss:0.581483
# [333]	validation_0-logloss:0.581557
# [334]	validation_0-logloss:0.581396
# [335]	validation_0-logloss:0.581102
# [336]	validation_0-logloss:0.580864
# [337]	validation_0-logloss:0.580901
# [338]	validation_0-logloss:0.580848
# [339]	validation_0-logloss:0.580833
# [340]	validation_0-logloss:0.580844
# [341]	validation_0-logloss:0.580766
# [342]	validation_0-logloss:0.5806
# [343]	validation_0-logloss:0.580496
# [344]	validation_0-logloss:0.580611
# [345]	validation_0-logloss:0.580594
# [346]	validation_0-logloss:0.580569
# [347]	validation_0-logloss:0.580518
# [348]	validation_0-logloss:0.580566
# [349]	validation_0-logloss:0.580456
# [350]	validation_0-logloss:0.580536
# [351]	validation_0-logloss:0.580458
# [352]	validation_0-logloss:0.580365
# [353]	validation_0-logloss:0.580308
# [354]	validation_0-logloss:0.58024
# [355]	validation_0-logloss:0.580221
# [356]	validation_0-logloss:0.580047
# [357]	validation_0-logloss:0.580042
# [358]	validation_0-logloss:0.580177
# [359]	validation_0-logloss:0.580237
# [360]	validation_0-logloss:0.580338
# [361]	validation_0-logloss:0.580183
# [362]	validation_0-logloss:0.580129
# [363]	validation_0-logloss:0.580108
# [364]	validation_0-logloss:0.579998
# [365]	validation_0-logloss:0.579896
# [366]	validation_0-logloss:0.579753
# [367]	validation_0-logloss:0.579823
# [368]	validation_0-logloss:0.579876
# [369]	validation_0-logloss:0.579784
# [370]	validation_0-logloss:0.579761
# [371]	validation_0-logloss:0.57961
# [372]	validation_0-logloss:0.579541
# [373]	validation_0-logloss:0.57934
# [374]	validation_0-logloss:0.579323
# [375]	validation_0-logloss:0.579235
# [376]	validation_0-logloss:0.579157
# [377]	validation_0-logloss:0.579123
# [378]	validation_0-logloss:0.579109
# [379]	validation_0-logloss:0.578961
# [380]	validation_0-logloss:0.578887
# [381]	validation_0-logloss:0.578716
# [382]	validation_0-logloss:0.578622
# [383]	validation_0-logloss:0.578476
# [384]	validation_0-logloss:0.578281
# [385]	validation_0-logloss:0.578214
# [386]	validation_0-logloss:0.578114
# [387]	validation_0-logloss:0.578114
# [388]	validation_0-logloss:0.578049
# [389]	validation_0-logloss:0.577962
# [390]	validation_0-logloss:0.577837
# [391]	validation_0-logloss:0.577725
# [392]	validation_0-logloss:0.577617
# [393]	validation_0-logloss:0.577548
# [394]	validation_0-logloss:0.577548
# [395]	validation_0-logloss:0.577439
# [396]	validation_0-logloss:0.577325
# [397]	validation_0-logloss:0.577204
# [398]	validation_0-logloss:0.577021
# [399]	validation_0-logloss:0.577039
# [400]	validation_0-logloss:0.577075
# [401]	validation_0-logloss:0.576984
# [402]	validation_0-logloss:0.576985
# [403]	validation_0-logloss:0.577051
# [404]	validation_0-logloss:0.577025
# [405]	validation_0-logloss:0.576927
# [406]	validation_0-logloss:0.57687
# [407]	validation_0-logloss:0.576831
# [408]	validation_0-logloss:0.5768
# [409]	validation_0-logloss:0.576725
# [410]	validation_0-logloss:0.576575
# [411]	validation_0-logloss:0.576312
# [412]	validation_0-logloss:0.576202
# [413]	validation_0-logloss:0.576159
# [414]	validation_0-logloss:0.576207
# [415]	validation_0-logloss:0.576209
# [416]	validation_0-logloss:0.576265
# [417]	validation_0-logloss:0.576207
# [418]	validation_0-logloss:0.576225
# [419]	validation_0-logloss:0.576204
# [420]	validation_0-logloss:0.576236
# [421]	validation_0-logloss:0.576102
# [422]	validation_0-logloss:0.57602
# [423]	validation_0-logloss:0.575973
# [424]	validation_0-logloss:0.57598
# [425]	validation_0-logloss:0.576027
# [426]	validation_0-logloss:0.576048
# [427]	validation_0-logloss:0.57595
# [428]	validation_0-logloss:0.576026
# [429]	validation_0-logloss:0.576102
# [430]	validation_0-logloss:0.576019
# [431]	validation_0-logloss:0.575966
# [432]	validation_0-logloss:0.575891
# [433]	validation_0-logloss:0.575787
# [434]	validation_0-logloss:0.575871
# [435]	validation_0-logloss:0.575657
# [436]	validation_0-logloss:0.575544
# [437]	validation_0-logloss:0.575533
# [438]	validation_0-logloss:0.575493
# [439]	validation_0-logloss:0.575501
# [440]	validation_0-logloss:0.575431
# [441]	validation_0-logloss:0.575549
# [442]	validation_0-logloss:0.575415
# [443]	validation_0-logloss:0.57541
# [444]	validation_0-logloss:0.575417
# [445]	validation_0-logloss:0.575372
# [446]	validation_0-logloss:0.575421
# [447]	validation_0-logloss:0.575363
# [448]	validation_0-logloss:0.5754
# [449]	validation_0-logloss:0.575316
# [450]	validation_0-logloss:0.575207
# [451]	validation_0-logloss:0.575201
# [452]	validation_0-logloss:0.57512
# [453]	validation_0-logloss:0.57509
# [454]	validation_0-logloss:0.57521
# [455]	validation_0-logloss:0.575281
# [456]	validation_0-logloss:0.575347
# [457]	validation_0-logloss:0.575417
# [458]	validation_0-logloss:0.575398
# [459]	validation_0-logloss:0.57537
# [460]	validation_0-logloss:0.575508
# [461]	validation_0-logloss:0.575399
# [462]	validation_0-logloss:0.575425
# [463]	validation_0-logloss:0.575426
# [464]	validation_0-logloss:0.575422
# [465]	validation_0-logloss:0.575548
# [466]	validation_0-logloss:0.575464
# [467]	validation_0-logloss:0.575475
# [468]	validation_0-logloss:0.575455
# [469]	validation_0-logloss:0.575554
# [470]	validation_0-logloss:0.575603
# [471]	validation_0-logloss:0.575537
# [472]	validation_0-logloss:0.575386
# [473]	validation_0-logloss:0.575422
# [474]	validation_0-logloss:0.575437
# [475]	validation_0-logloss:0.575428
# [476]	validation_0-logloss:0.575442
# [477]	validation_0-logloss:0.575425
# [478]	validation_0-logloss:0.575412
# [479]	validation_0-logloss:0.575475
# [480]	validation_0-logloss:0.5754
# [481]	validation_0-logloss:0.575537
# [482]	validation_0-logloss:0.575382
# [483]	validation_0-logloss:0.575276
# [484]	validation_0-logloss:0.575202
# [485]	validation_0-logloss:0.57518
# [486]	validation_0-logloss:0.575145
# [487]	validation_0-logloss:0.575177
# [488]	validation_0-logloss:0.575127
# [489]	validation_0-logloss:0.574916
# [490]	validation_0-logloss:0.574952
# [491]	validation_0-logloss:0.575056
# [492]	validation_0-logloss:0.575163
# [493]	validation_0-logloss:0.575033
# [494]	validation_0-logloss:0.575241
# [495]	validation_0-logloss:0.575192
# [496]	validation_0-logloss:0.575283
# [497]	validation_0-logloss:0.575353
# [498]	validation_0-logloss:0.575277
# [499]	validation_0-logloss:0.57518
# [500]	validation_0-logloss:0.575103
# [501]	validation_0-logloss:0.575233
# [502]	validation_0-logloss:0.575303
# [503]	validation_0-logloss:0.575406
# [504]	validation_0-logloss:0.575447
# [505]	validation_0-logloss:0.575331
# [506]	validation_0-logloss:0.575297
# [507]	validation_0-logloss:0.575287
# [508]	validation_0-logloss:0.575333
# [509]	validation_0-logloss:0.5754
# [510]	validation_0-logloss:0.575232
# [511]	validation_0-logloss:0.575278
# [512]	validation_0-logloss:0.575324
# [513]	validation_0-logloss:0.575148
# [514]	validation_0-logloss:0.575062
# [515]	validation_0-logloss:0.575083
# [516]	validation_0-logloss:0.575153
# [517]	validation_0-logloss:0.574972
# [518]	validation_0-logloss:0.575043
# [519]	validation_0-logloss:0.57504
# [520]	validation_0-logloss:0.575052
# [521]	validation_0-logloss:0.575067
# [522]	validation_0-logloss:0.575206
# [523]	validation_0-logloss:0.575192
# [524]	validation_0-logloss:0.575253
# [525]	validation_0-logloss:0.575361
# [526]	validation_0-logloss:0.575463
# [527]	validation_0-logloss:0.575404
# [528]	validation_0-logloss:0.57548
# [529]	validation_0-logloss:0.575467
# [530]	validation_0-logloss:0.575604
# [531]	validation_0-logloss:0.57555
# [532]	validation_0-logloss:0.575536
# [533]	validation_0-logloss:0.575595
# [534]	validation_0-logloss:0.575568
# [535]	validation_0-logloss:0.5757
# [536]	validation_0-logloss:0.575778
# [537]	validation_0-logloss:0.575821
# [538]	validation_0-logloss:0.575899
# [539]	validation_0-logloss:0.575857
# Stopping. Best iteration:
# [489]	validation_0-logloss:0.574916

# %%
val_y_pred = clf.predict(val_x)

# %%
for i in range(val_y.shape[0]):
    if val_y[i] == 1:
        print("val_y:", val_y[i], "val_y_pred:",val_y_pred[i], "delta: ", val_y[i]-val_y_pred[i])
# Out:
# val_y: [1] val_y_pred: 0.222239 delta:  [ 0.77776082]
# val_y: [1] val_y_pred: 0.303293 delta:  [ 0.69670656]
# val_y: [1] val_y_pred: 0.282054 delta:  [ 0.71794647]
# val_y: [1] val_y_pred: 0.249711 delta:  [ 0.75028872]
# val_y: [1] val_y_pred: 0.192385 delta:  [ 0.80761459]
# val_y: [1] val_y_pred: 0.242492 delta:  [ 0.75750843]
# val_y: [1] val_y_pred: 0.233661 delta:  [ 0.76633893]
# val_y: [1] val_y_pred: 0.241637 delta:  [ 0.75836256]
# val_y: [1] val_y_pred: 0.287786 delta:  [ 0.71221438]
# val_y: [1] val_y_pred: 0.214457 delta:  [ 0.78554285]
# val_y: [1] val_y_pred: 0.188477 delta:  [ 0.81152284]
# val_y: [1] val_y_pred: 0.276844 delta:  [ 0.72315568]
# val_y: [1] val_y_pred: 0.243648 delta:  [ 0.75635196]
# val_y: [1] val_y_pred: 0.260991 delta:  [ 0.73900861]
# val_y: [1] val_y_pred: 0.222122 delta:  [ 0.77787833]
# val_y: [1] val_y_pred: 0.185716 delta:  [ 0.81428377]
# val_y: [1] val_y_pred: 0.157877 delta:  [ 0.84212282]
# val_y: [1] val_y_pred: 0.21681 delta:  [ 0.78319]
# val_y: [1] val_y_pred: 0.275285 delta:  [ 0.72471467]
# val_y: [1] val_y_pred: 0.365141 delta:  [ 0.63485926]
# val_y: [1] val_y_pred: 0.20785 delta:  [ 0.79214951]
# val_y: [1] val_y_pred: 0.22351 delta:  [ 0.77648965]
# val_y: [1] val_y_pred: 0.300293 delta:  [ 0.69970673]
# val_y: [1] val_y_pred: 0.34089 delta:  [ 0.65910971]
# val_y: [1] val_y_pred: 0.193446 delta:  [ 0.80655421]
# val_y: [1] val_y_pred: 0.253978 delta:  [ 0.74602216]
# val_y: [1] val_y_pred: 0.270661 delta:  [ 0.72933918]
# val_y: [1] val_y_pred: 0.203206 delta:  [ 0.79679365]
# val_y: [1] val_y_pred: 0.284965 delta:  [ 0.71503451]
# val_y: [1] val_y_pred: 0.268332 delta:  [ 0.73166761]
# val_y: [1] val_y_pred: 0.465966 delta:  [ 0.53403389]
# val_y: [1] val_y_pred: 0.383801 delta:  [ 0.61619934]
# val_y: [1] val_y_pred: 0.342177 delta:  [ 0.65782291]
# val_y: [1] val_y_pred: 0.197544 delta:  [ 0.8024559]
# val_y: [1] val_y_pred: 0.220091 delta:  [ 0.77990937]
# val_y: [1] val_y_pred: 0.295472 delta:  [ 0.70452768]
# val_y: [1] val_y_pred: 0.338064 delta:  [ 0.66193625]
# val_y: [1] val_y_pred: 0.276976 delta:  [ 0.72302419]
# val_y: [1] val_y_pred: 0.265502 delta:  [ 0.73449817]
# val_y: [1] val_y_pred: 0.351451 delta:  [ 0.6485486]
# val_y: [1] val_y_pred: 0.203218 delta:  [ 0.79678157]
# val_y: [1] val_y_pred: 0.252099 delta:  [ 0.74790058]
# val_y: [1] val_y_pred: 0.310471 delta:  [ 0.68952909]
# val_y: [1] val_y_pred: 0.226913 delta:  [ 0.77308688]
# val_y: [1] val_y_pred: 0.329595 delta:  [ 0.67040515]
# val_y: [1] val_y_pred: 0.203849 delta:  [ 0.79615128]
# val_y: [1] val_y_pred: 0.240073 delta:  [ 0.75992738]
# val_y: [1] val_y_pred: 0.325322 delta:  [ 0.6746783]
# val_y: [1] val_y_pred: 0.314941 delta:  [ 0.68505856]
# val_y: [1] val_y_pred: 0.205708 delta:  [ 0.7942922]
# val_y: [1] val_y_pred: 0.390511 delta:  [ 0.60948911]
# val_y: [1] val_y_pred: 0.194535 delta:  [ 0.80546506]
# val_y: [1] val_y_pred: 0.282626 delta:  [ 0.71737438]
# val_y: [1] val_y_pred: 0.261144 delta:  [ 0.73885572]
# val_y: [1] val_y_pred: 0.237093 delta:  [ 0.76290715]
# val_y: [1] val_y_pred: 0.269347 delta:  [ 0.73065281]
# val_y: [1] val_y_pred: 0.232683 delta:  [ 0.7673168]
# val_y: [1] val_y_pred: 0.277219 delta:  [ 0.72278097]
# val_y: [1] val_y_pred: 0.343587 delta:  [ 0.65641284]
# val_y: [1] val_y_pred: 0.297042 delta:  [ 0.70295823]
# val_y: [1] val_y_pred: 0.278021 delta:  [ 0.72197875]
# val_y: [1] val_y_pred: 0.372471 delta:  [ 0.62752929]
# val_y: [1] val_y_pred: 0.189908 delta:  [ 0.81009214]
# val_y: [1] val_y_pred: 0.285729 delta:  [ 0.71427113]
# val_y: [1] val_y_pred: 0.331508 delta:  [ 0.66849169]
# val_y: [1] val_y_pred: 0.277106 delta:  [ 0.72289419]
# val_y: [1] val_y_pred: 0.350893 delta:  [ 0.64910707]
# val_y: [1] val_y_pred: 0.149719 delta:  [ 0.85028136]
# val_y: [1] val_y_pred: 0.293237 delta:  [ 0.70676345]
# val_y: [1] val_y_pred: 0.223346 delta:  [ 0.77665386]
# val_y: [1] val_y_pred: 0.232071 delta:  [ 0.76792946]
# val_y: [1] val_y_pred: 0.202733 delta:  [ 0.79726742]
# val_y: [1] val_y_pred: 0.208189 delta:  [ 0.79181071]

# %%
np.mean(val_y_pred)
# Out:
# 0.26005074

# %%
for i in range(val_y.shape[0]):
    if val_y[i] == 0:
        print("val_y:", val_y[i], "val_y_pred:",val_y_pred[i], "delta: ", val_y[i]- val_y_pred[i])
# Out:
# val_y: [0] val_y_pred: 0.233237 delta:  [-0.23323727]
# val_y: [0] val_y_pred: 0.20158 delta:  [-0.20158035]
# val_y: [0] val_y_pred: 0.23412 delta:  [-0.23412016]
# val_y: [0] val_y_pred: 0.187155 delta:  [-0.18715458]
# val_y: [0] val_y_pred: 0.304777 delta:  [-0.30477697]
# val_y: [0] val_y_pred: 0.270852 delta:  [-0.27085215]
# val_y: [0] val_y_pred: 0.322837 delta:  [-0.32283682]
# val_y: [0] val_y_pred: 0.210034 delta:  [-0.2100341]
# val_y: [0] val_y_pred: 0.185119 delta:  [-0.18511911]
# val_y: [0] val_y_pred: 0.370859 delta:  [-0.37085864]
# val_y: [0] val_y_pred: 0.407247 delta:  [-0.40724736]
# val_y: [0] val_y_pred: 0.181321 delta:  [-0.1813212]
# val_y: [0] val_y_pred: 0.257239 delta:  [-0.25723866]
# val_y: [0] val_y_pred: 0.300386 delta:  [-0.30038613]
# val_y: [0] val_y_pred: 0.287355 delta:  [-0.28735548]
# val_y: [0] val_y_pred: 0.288387 delta:  [-0.28838667]
# val_y: [0] val_y_pred: 0.330905 delta:  [-0.33090457]
# val_y: [0] val_y_pred: 0.289419 delta:  [-0.28941914]
# val_y: [0] val_y_pred: 0.258767 delta:  [-0.25876704]
# val_y: [0] val_y_pred: 0.192196 delta:  [-0.192196]
# val_y: [0] val_y_pred: 0.28801 delta:  [-0.28800988]
# val_y: [0] val_y_pred: 0.28272 delta:  [-0.28272018]
# val_y: [0] val_y_pred: 0.267832 delta:  [-0.26783183]
# val_y: [0] val_y_pred: 0.191386 delta:  [-0.19138551]
# val_y: [0] val_y_pred: 0.192464 delta:  [-0.19246396]
# val_y: [0] val_y_pred: 0.295445 delta:  [-0.29544482]
# val_y: [0] val_y_pred: 0.314398 delta:  [-0.31439778]
# val_y: [0] val_y_pred: 0.269842 delta:  [-0.26984248]
# val_y: [0] val_y_pred: 0.211331 delta:  [-0.21133053]
# val_y: [0] val_y_pred: 0.191332 delta:  [-0.19133241]
# val_y: [0] val_y_pred: 0.184988 delta:  [-0.18498787]
# val_y: [0] val_y_pred: 0.308594 delta:  [-0.30859426]
# val_y: [0] val_y_pred: 0.266379 delta:  [-0.26637894]
# val_y: [0] val_y_pred: 0.229165 delta:  [-0.2291646]
# val_y: [0] val_y_pred: 0.265902 delta:  [-0.26590216]
# val_y: [0] val_y_pred: 0.170594 delta:  [-0.17059366]
# val_y: [0] val_y_pred: 0.212319 delta:  [-0.21231878]
# val_y: [0] val_y_pred: 0.180999 delta:  [-0.18099897]
# val_y: [0] val_y_pred: 0.327851 delta:  [-0.32785118]
# val_y: [0] val_y_pred: 0.190604 delta:  [-0.19060445]
# val_y: [0] val_y_pred: 0.341995 delta:  [-0.34199545]
# val_y: [0] val_y_pred: 0.319958 delta:  [-0.31995806]
# val_y: [0] val_y_pred: 0.191295 delta:  [-0.19129509]
# val_y: [0] val_y_pred: 0.154006 delta:  [-0.15400577]
# val_y: [0] val_y_pred: 0.181838 delta:  [-0.18183808]
# val_y: [0] val_y_pred: 0.29764 delta:  [-0.29764014]
# val_y: [0] val_y_pred: 0.195514 delta:  [-0.19551428]
# val_y: [0] val_y_pred: 0.292691 delta:  [-0.2926915]
# val_y: [0] val_y_pred: 0.263283 delta:  [-0.26328257]
# val_y: [0] val_y_pred: 0.416272 delta:  [-0.4162724]
# val_y: [0] val_y_pred: 0.405189 delta:  [-0.40518859]
# val_y: [0] val_y_pred: 0.225924 delta:  [-0.22592369]
# val_y: [0] val_y_pred: 0.243955 delta:  [-0.24395533]
# val_y: [0] val_y_pred: 0.255833 delta:  [-0.25583303]
# val_y: [0] val_y_pred: 0.208661 delta:  [-0.20866054]
# val_y: [0] val_y_pred: 0.285855 delta:  [-0.28585455]
# val_y: [0] val_y_pred: 0.307238 delta:  [-0.30723798]
# val_y: [0] val_y_pred: 0.260489 delta:  [-0.26048949]
# val_y: [0] val_y_pred: 0.276193 delta:  [-0.2761929]
# val_y: [0] val_y_pred: 0.279123 delta:  [-0.27912337]
# val_y: [0] val_y_pred: 0.316058 delta:  [-0.31605786]
# val_y: [0] val_y_pred: 0.195804 delta:  [-0.19580425]
# val_y: [0] val_y_pred: 0.332916 delta:  [-0.3329159]
# val_y: [0] val_y_pred: 0.263018 delta:  [-0.26301759]
# val_y: [0] val_y_pred: 0.291381 delta:  [-0.29138067]
# val_y: [0] val_y_pred: 0.244393 delta:  [-0.24439329]
# val_y: [0] val_y_pred: 0.225778 delta:  [-0.22577766]
# val_y: [0] val_y_pred: 0.229153 delta:  [-0.22915301]
# val_y: [0] val_y_pred: 0.25155 delta:  [-0.25154993]
# val_y: [0] val_y_pred: 0.248689 delta:  [-0.24868858]
# val_y: [0] val_y_pred: 0.232994 delta:  [-0.23299405]
# val_y: [0] val_y_pred: 0.213628 delta:  [-0.21362814]
# val_y: [0] val_y_pred: 0.195697 delta:  [-0.1956965]
# val_y: [0] val_y_pred: 0.222785 delta:  [-0.2227852]
# val_y: [0] val_y_pred: 0.295663 delta:  [-0.29566345]
# val_y: [0] val_y_pred: 0.307949 delta:  [-0.30794907]
# val_y: [0] val_y_pred: 0.242658 delta:  [-0.24265847]
# val_y: [0] val_y_pred: 0.216617 delta:  [-0.21661691]
# val_y: [0] val_y_pred: 0.259998 delta:  [-0.25999752]
# val_y: [0] val_y_pred: 0.28329 delta:  [-0.28328982]
# val_y: [0] val_y_pred: 0.298137 delta:  [-0.29813671]
# val_y: [0] val_y_pred: 0.229721 delta:  [-0.22972149]
# val_y: [0] val_y_pred: 0.273781 delta:  [-0.27378118]
# val_y: [0] val_y_pred: 0.203082 delta:  [-0.2030815]
# val_y: [0] val_y_pred: 0.411263 delta:  [-0.4112635]
# val_y: [0] val_y_pred: 0.212326 delta:  [-0.21232578]
# val_y: [0] val_y_pred: 0.271289 delta:  [-0.2712889]
# val_y: [0] val_y_pred: 0.360057 delta:  [-0.36005738]
# val_y: [0] val_y_pred: 0.292447 delta:  [-0.29244727]
# val_y: [0] val_y_pred: 0.236801 delta:  [-0.23680089]
# val_y: [0] val_y_pred: 0.243043 delta:  [-0.24304323]
# val_y: [0] val_y_pred: 0.278903 delta:  [-0.27890313]
# val_y: [0] val_y_pred: 0.419969 delta:  [-0.41996923]
# val_y: [0] val_y_pred: 0.285127 delta:  [-0.28512743]
# val_y: [0] val_y_pred: 0.212189 delta:  [-0.21218881]
# val_y: [0] val_y_pred: 0.257049 delta:  [-0.25704947]
# val_y: [0] val_y_pred: 0.228506 delta:  [-0.22850583]
# val_y: [0] val_y_pred: 0.199893 delta:  [-0.19989347]
# val_y: [0] val_y_pred: 0.281268 delta:  [-0.2812677]
# val_y: [0] val_y_pred: 0.260992 delta:  [-0.26099181]
# val_y: [0] val_y_pred: 0.336836 delta:  [-0.33683604]
# val_y: [0] val_y_pred: 0.251701 delta:  [-0.25170133]
# val_y: [0] val_y_pred: 0.240219 delta:  [-0.2402187]
# val_y: [0] val_y_pred: 0.244229 delta:  [-0.24422926]
# val_y: [0] val_y_pred: 0.213936 delta:  [-0.21393636]
# val_y: [0] val_y_pred: 0.292526 delta:  [-0.29252586]
# val_y: [0] val_y_pred: 0.284811 delta:  [-0.28481111]
# val_y: [0] val_y_pred: 0.23008 delta:  [-0.23008025]
# val_y: [0] val_y_pred: 0.237759 delta:  [-0.23775886]
# val_y: [0] val_y_pred: 0.21731 delta:  [-0.21730983]
# val_y: [0] val_y_pred: 0.139976 delta:  [-0.13997649]
# val_y: [0] val_y_pred: 0.203772 delta:  [-0.20377201]
# val_y: [0] val_y_pred: 0.269602 delta:  [-0.26960206]
# val_y: [0] val_y_pred: 0.179869 delta:  [-0.17986915]
# val_y: [0] val_y_pred: 0.261983 delta:  [-0.26198262]
# val_y: [0] val_y_pred: 0.281785 delta:  [-0.28178498]
# val_y: [0] val_y_pred: 0.283301 delta:  [-0.28330061]
# val_y: [0] val_y_pred: 0.337674 delta:  [-0.33767354]
# val_y: [0] val_y_pred: 0.218962 delta:  [-0.21896228]
# val_y: [0] val_y_pred: 0.220928 delta:  [-0.22092763]
# val_y: [0] val_y_pred: 0.174382 delta:  [-0.1743816]
# val_y: [0] val_y_pred: 0.251813 delta:  [-0.25181326]
# val_y: [0] val_y_pred: 0.256802 delta:  [-0.2568025]
# val_y: [0] val_y_pred: 0.336068 delta:  [-0.33606756]
# val_y: [0] val_y_pred: 0.273046 delta:  [-0.27304563]
# val_y: [0] val_y_pred: 0.192969 delta:  [-0.19296876]
# val_y: [0] val_y_pred: 0.266461 delta:  [-0.26646087]
# val_y: [0] val_y_pred: 0.251728 delta:  [-0.25172821]
# val_y: [0] val_y_pred: 0.302761 delta:  [-0.30276072]
# val_y: [0] val_y_pred: 0.245021 delta:  [-0.24502081]
# val_y: [0] val_y_pred: 0.163395 delta:  [-0.16339462]
# val_y: [0] val_y_pred: 0.212592 delta:  [-0.21259187]
# val_y: [0] val_y_pred: 0.198288 delta:  [-0.19828774]
# val_y: [0] val_y_pred: 0.343866 delta:  [-0.34386578]
# val_y: [0] val_y_pred: 0.234998 delta:  [-0.23499848]
# val_y: [0] val_y_pred: 0.215739 delta:  [-0.21573921]
# val_y: [0] val_y_pred: 0.274143 delta:  [-0.27414301]
# val_y: [0] val_y_pred: 0.205976 delta:  [-0.20597611]
# val_y: [0] val_y_pred: 0.308337 delta:  [-0.30833715]
# val_y: [0] val_y_pred: 0.239652 delta:  [-0.2396525]
# val_y: [0] val_y_pred: 0.299117 delta:  [-0.29911679]
# val_y: [0] val_y_pred: 0.194429 delta:  [-0.19442871]
# val_y: [0] val_y_pred: 0.210205 delta:  [-0.21020481]
# val_y: [0] val_y_pred: 0.332257 delta:  [-0.33225676]
# val_y: [0] val_y_pred: 0.195423 delta:  [-0.19542329]
# val_y: [0] val_y_pred: 0.333598 delta:  [-0.33359841]
# val_y: [0] val_y_pred: 0.316598 delta:  [-0.31659788]
# val_y: [0] val_y_pred: 0.294629 delta:  [-0.29462859]
# val_y: [0] val_y_pred: 0.28495 delta:  [-0.28495014]
# val_y: [0] val_y_pred: 0.238771 delta:  [-0.2387715]
# val_y: [0] val_y_pred: 0.209507 delta:  [-0.2095066]
# val_y: [0] val_y_pred: 0.170466 delta:  [-0.17046551]
# val_y: [0] val_y_pred: 0.308183 delta:  [-0.30818349]
# val_y: [0] val_y_pred: 0.23629 delta:  [-0.23629025]
# val_y: [0] val_y_pred: 0.178955 delta:  [-0.17895506]
# val_y: [0] val_y_pred: 0.24694 delta:  [-0.24694034]
# val_y: [0] val_y_pred: 0.213362 delta:  [-0.21336205]
# val_y: [0] val_y_pred: 0.273738 delta:  [-0.27373764]
# val_y: [0] val_y_pred: 0.308281 delta:  [-0.30828121]
# val_y: [0] val_y_pred: 0.383699 delta:  [-0.38369918]
# val_y: [0] val_y_pred: 0.211345 delta:  [-0.21134527]
# val_y: [0] val_y_pred: 0.229748 delta:  [-0.22974804]
# val_y: [0] val_y_pred: 0.221964 delta:  [-0.22196405]
# val_y: [0] val_y_pred: 0.259634 delta:  [-0.25963438]
# val_y: [0] val_y_pred: 0.250465 delta:  [-0.25046539]
# val_y: [0] val_y_pred: 0.220244 delta:  [-0.2202445]
# val_y: [0] val_y_pred: 0.206546 delta:  [-0.20654605]
# val_y: [0] val_y_pred: 0.209282 delta:  [-0.20928165]
# val_y: [0] val_y_pred: 0.225323 delta:  [-0.2253233]
# val_y: [0] val_y_pred: 0.226811 delta:  [-0.22681108]
# val_y: [0] val_y_pred: 0.282607 delta:  [-0.2826066]
# val_y: [0] val_y_pred: 0.240979 delta:  [-0.24097855]
# val_y: [0] val_y_pred: 0.223113 delta:  [-0.22311263]
# val_y: [0] val_y_pred: 0.388011 delta:  [-0.38801128]
# val_y: [0] val_y_pred: 0.17282 delta:  [-0.17281988]
# val_y: [0] val_y_pred: 0.233881 delta:  [-0.23388089]
# val_y: [0] val_y_pred: 0.282932 delta:  [-0.28293195]
# val_y: [0] val_y_pred: 0.335435 delta:  [-0.335435]
# val_y: [0] val_y_pred: 0.324847 delta:  [-0.32484707]
# val_y: [0] val_y_pred: 0.194132 delta:  [-0.1941319]
# val_y: [0] val_y_pred: 0.245617 delta:  [-0.24561653]
# val_y: [0] val_y_pred: 0.299299 delta:  [-0.29929924]
# val_y: [0] val_y_pred: 0.306808 delta:  [-0.30680814]
# val_y: [0] val_y_pred: 0.242257 delta:  [-0.24225655]
# val_y: [0] val_y_pred: 0.244923 delta:  [-0.24492286]
# val_y: [0] val_y_pred: 0.259304 delta:  [-0.2593044]
# val_y: [0] val_y_pred: 0.391294 delta:  [-0.39129415]
# val_y: [0] val_y_pred: 0.266659 delta:  [-0.26665929]
# val_y: [0] val_y_pred: 0.234667 delta:  [-0.23466702]
# val_y: [0] val_y_pred: 0.235656 delta:  [-0.23565613]
# val_y: [0] val_y_pred: 0.268878 delta:  [-0.26887816]
# val_y: [0] val_y_pred: 0.255493 delta:  [-0.25549322]
# val_y: [0] val_y_pred: 0.264366 delta:  [-0.26436558]
# val_y: [0] val_y_pred: 0.243887 delta:  [-0.24388671]
# val_y: [0] val_y_pred: 0.337743 delta:  [-0.33774346]
# val_y: [0] val_y_pred: 0.236668 delta:  [-0.23666795]
# val_y: [0] val_y_pred: 0.277313 delta:  [-0.27731323]
# val_y: [0] val_y_pred: 0.305485 delta:  [-0.30548504]
# val_y: [0] val_y_pred: 0.189232 delta:  [-0.18923226]
# val_y: [0] val_y_pred: 0.314461 delta:  [-0.31446132]
# val_y: [0] val_y_pred: 0.253193 delta:  [-0.25319305]
# val_y: [0] val_y_pred: 0.290977 delta:  [-0.29097742]
# val_y: [0] val_y_pred: 0.265538 delta:  [-0.26553801]
# val_y: [0] val_y_pred: 0.208635 delta:  [-0.20863488]
# val_y: [0] val_y_pred: 0.352425 delta:  [-0.35242456]
# val_y: [0] val_y_pred: 0.258835 delta:  [-0.25883502]
# val_y: [0] val_y_pred: 0.275305 delta:  [-0.27530479]

# %%
for i in range(val_y.shape[0]):
    if val_y[i] == 0:
        val_y_pred[i] = 0.00001
    print(val_y_pred[i])
# Out:
# 1e-05
# 0.222239
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.303293
# 1e-05
# 1e-05
# 0.282054
# 1e-05
# 0.249711
# 1e-05
# 0.192385
# 0.242492
# 1e-05
# 1e-05
# 0.233661
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.241637
# 1e-05
# 0.287786
# 1e-05
# 0.214457
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.188477
# 1e-05
# 1e-05
# 1e-05
# 0.276844
# 0.243648
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.260991
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.222122
# 1e-05
# 1e-05
# 1e-05
# 0.185716
# 1e-05
# 0.157877
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.21681
# 1e-05
# 0.275285
# 0.365141
# 1e-05
# 1e-05
# 0.20785
# 1e-05
# 1e-05
# 0.22351
# 1e-05
# 0.300293
# 1e-05
# 1e-05
# 1e-05
# 0.34089
# 1e-05
# 1e-05
# 0.193446
# 1e-05
# 1e-05
# 0.253978
# 1e-05
# 1e-05
# 1e-05
# 0.270661
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.203206
# 1e-05
# 1e-05
# 1e-05
# 0.284965
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.268332
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.465966
# 1e-05
# 1e-05
# 1e-05
# 0.383801
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.342177
# 1e-05
# 0.197544
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.220091
# 1e-05
# 1e-05
# 0.295472
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.338064
# 1e-05
# 0.276976
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.265502
# 1e-05
# 0.351451
# 1e-05
# 1e-05
# 0.203218
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.252099
# 1e-05
# 0.310471
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.226913
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.329595
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.203849
# 0.240073
# 1e-05
# 1e-05
# 0.325322
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.314941
# 1e-05
# 0.205708
# 1e-05
# 0.390511
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.194535
# 0.282626
# 1e-05
# 0.261144
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.237093
# 1e-05
# 0.269347
# 0.232683
# 1e-05
# 1e-05
# 1e-05
# 0.277219
# 0.343587
# 0.297042
# 1e-05
# 0.278021
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.372471
# 1e-05
# 0.189908
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.285729
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.331508
# 1e-05
# 1e-05
# 0.277106
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.350893
# 1e-05
# 0.149719
# 0.293237
# 1e-05
# 1e-05
# 1e-05
# 1e-05
# 0.223346
# 0.232071
# 1e-05
# 1e-05
# 0.202733
# 1e-05
# 0.208189

# %%
sklearn.metrics.log_loss(val_y,val_y_pred,eps=1e-15)
# Out:
# 0.35286705710498806
